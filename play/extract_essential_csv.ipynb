# %%
import pandas as pd
import json
from datetime import datetime
import random
import copy

# %%
D = {}
with open('data.jl',encoding='utf-8') as f:
    for l in f.readlines():
        try:
            j = json.loads(l)
            pkgname = j['pkg']
            D[pkgname] = j
        except:
            pass
len(D)
# Out:
# 642744

# %%
D['com.facebook.orca']
# Out:
# {'name': 'Messenger – Text and Video Chat for Free',
#  'pkg': 'com.facebook.orca',
#  'publisher': 'Facebook',
#  'genres': ['Communication'],
#  'content_ratings': ['Everyone'],
#  'is_editor_choice': True,
#  'price': 0.0,
#  'inapp_details': ['Offers in-app purchases'],
#  'has_video': False,
#  'num_screenshot': 8,
#  'description': "* SEND A MESSAGE -Skip exchanging phone numbers, just send a message. It's seamless across devices.\n* SHOW YOUR REACTION - Add a silly sticker, send a dancing GIF and use emojis to express yourself better.\n* SHARE PHOTOS AND VIDEOS - Capture the moment with the Messenger Camera, add a filter or doodle, then send to friends or share to Stories.\n* RALLY THE GROUP - Make plans to get together with polls, share your location, split the bill and more.\n* HOP ON A CALL OR VIDEO CHAT - Hang out anywhere, anytime by getting on call or a group video** chat — filters optional :) **Calls are free over Wi-Fi but otherwise standard data charges apply.\n* SEND A VOICE MESSAGE - When text just won't cut it, just hit record and send say, sing or shout it out loud.\n* SEND MONEY SECURELY AND EASILY (within US, UK and France only) - Send and receive money from friends in the app by adding your debit card or PayPal* account. *PayPal available in the US only.\n* SHARE YOUR LOCATION - Suggest a meeting spot or tell friends where you are by sharing your location with just a few taps.\n* CHAT WITH BUSINESSES - Easily connect with your favorite businesses to make reservations, get customer support, find deals and more.\n* PLAY GAMES WITH FRIENDS - Challenge friends, climb leaderboards, and discover your next gaming obsession.\n* BRING SMS INTO MESSENGER - No need to open multiple apps to stay in touch. Use one app for SMS and Messenger.",
#  'rating_overall': 4.1,
#  'rating_5': 40250992,
#  'rating_4': 9365883,
#  'rating_3': 6007039,
#  'rating_2': 2502559,
#  'rating_1': 7830646,
#  'rating_count': 65957119,
#  'additional_info': {'Updated': 'April 23, 2019',
#   'Size': 'Varies with device',
#   'Installs': '1,000,000,000+',
#   'Current Version': 'Varies with device',
#   'Requires Android': 'Varies with device',
#   'Content Rating': 'Everyone\nLearn More',
#   'Interactive Elements': 'Users Interact, Shares Location, Digital Purchases',
#   'In-app Products': '$0.99 - $399.99 per item',
#   'Permissions': 'View details',
#   'Report': 'Flag as inappropriate',
#   'Offered By': 'Facebook',
#   'Developer': 'Visit website\nandroid-support@fb.com\nPrivacy Policy\n1 Hacker Way Menlo Park, CA 94025'}}

# %%
# D1 expands meaningful fields in additional_info out as top level keys, gets rid of description
D1 = dict()
for pkg in D:
    j = D[pkg]
    new_j = dict()
    for tlkey in j: # top level key of the line of json denoting an object
        if tlkey == 'additional_info':
            for aikey in j[tlkey]: # key inside 'additional_info':
                # filter out useless additional info
                if aikey not in ['Report', 'Permissions', 'Content Rating', 
                                 'Developer', 'Offered By', 'Eligible for Family Library']: 
                    new_j[aikey] = j[tlkey][aikey]
        elif tlkey == 'description': # no need for description in the essential csv
            continue
        else:
            new_j[tlkey] = j[tlkey]
    D1[pkg] = new_j
len(D1)
# Out:
# 642744

# %%
D1['com.facebook.orca']
# Out:
# {'name': 'Messenger – Text and Video Chat for Free',
#  'pkg': 'com.facebook.orca',
#  'publisher': 'Facebook',
#  'genres': ['Communication'],
#  'content_ratings': ['Everyone'],
#  'is_editor_choice': True,
#  'price': 0.0,
#  'inapp_details': ['Offers in-app purchases'],
#  'has_video': False,
#  'num_screenshot': 8,
#  'rating_overall': 4.1,
#  'rating_5': 40250992,
#  'rating_4': 9365883,
#  'rating_3': 6007039,
#  'rating_2': 2502559,
#  'rating_1': 7830646,
#  'rating_count': 65957119,
#  'Updated': 'April 23, 2019',
#  'Size': 'Varies with device',
#  'Installs': '1,000,000,000+',
#  'Current Version': 'Varies with device',
#  'Requires Android': 'Varies with device',
#  'Interactive Elements': 'Users Interact, Shares Location, Digital Purchases',
#  'In-app Products': '$0.99 - $399.99 per item'}

# %%
# there can be 2 genres and 2 content_rating, multiple inapp details 
# extracts it into a single field as the first one in the list in case there are two and save it in place in D1
for pkg in D1:
    j = D1[pkg]
    if len(j['genres']) == 0:
        j['genres'] = 'unknown'
    else:
        j['genres'] = j['genres'][0]
    j['content_ratings'] = j['content_ratings'][0]
    if len(j['inapp_details']) == 0:
        j['inapp_details'] = 'null'
    else:
        j['inapp_details'] = j['inapp_details'][0]
len(D1)
# Out:
# 642744

# %%
D1['com.facebook.orca']
# Out:
# {'name': 'Messenger – Text and Video Chat for Free',
#  'pkg': 'com.facebook.orca',
#  'publisher': 'Facebook',
#  'genres': 'Communication',
#  'content_ratings': 'Everyone',
#  'is_editor_choice': True,
#  'price': 0.0,
#  'inapp_details': 'Offers in-app purchases',
#  'has_video': False,
#  'num_screenshot': 8,
#  'rating_overall': 4.1,
#  'rating_5': 40250992,
#  'rating_4': 9365883,
#  'rating_3': 6007039,
#  'rating_2': 2502559,
#  'rating_1': 7830646,
#  'rating_count': 65957119,
#  'Updated': 'April 23, 2019',
#  'Size': 'Varies with device',
#  'Installs': '1,000,000,000+',
#  'Current Version': 'Varies with device',
#  'Requires Android': 'Varies with device',
#  'Interactive Elements': 'Users Interact, Shares Location, Digital Purchases',
#  'In-app Products': '$0.99 - $399.99 per item'}

# %%
# converts time to yyyy-mm-dd in place in D1
for pkg in D1:
    j = D1[pkg]
    t = datetime.strptime(j['Updated'], '%B %d, %Y')
    j['Updated'] = t.strftime('%Y-%m-%d')

# %%
D1['com.facebook.orca']
# Out:
# {'name': 'Messenger – Text and Video Chat for Free',
#  'pkg': 'com.facebook.orca',
#  'publisher': 'Facebook',
#  'genres': 'Communication',
#  'content_ratings': 'Everyone',
#  'is_editor_choice': True,
#  'price': 0.0,
#  'inapp_details': 'Offers in-app purchases',
#  'has_video': False,
#  'num_screenshot': 8,
#  'rating_overall': 4.1,
#  'rating_5': 40250992,
#  'rating_4': 9365883,
#  'rating_3': 6007039,
#  'rating_2': 2502559,
#  'rating_1': 7830646,
#  'rating_count': 65957119,
#  'Updated': '2019-04-23',
#  'Size': 'Varies with device',
#  'Installs': '1,000,000,000+',
#  'Current Version': 'Varies with device',
#  'Requires Android': 'Varies with device',
#  'Interactive Elements': 'Users Interact, Shares Location, Digital Purchases',
#  'In-app Products': '$0.99 - $399.99 per item'}

# %%
# convert installs by stripping the + and ,s then into an int
for pkg in D1:
    j = D1[pkg]
    n = j['Installs'].replace(',','').replace('+','')
    j['Installs'] = int(n)

# %%
D1['com.facebook.orca']
# Out:
# {'name': 'Messenger – Text and Video Chat for Free',
#  'pkg': 'com.facebook.orca',
#  'publisher': 'Facebook',
#  'genres': 'Communication',
#  'content_ratings': 'Everyone',
#  'is_editor_choice': True,
#  'price': 0.0,
#  'inapp_details': 'Offers in-app purchases',
#  'has_video': False,
#  'num_screenshot': 8,
#  'rating_overall': 4.1,
#  'rating_5': 40250992,
#  'rating_4': 9365883,
#  'rating_3': 6007039,
#  'rating_2': 2502559,
#  'rating_1': 7830646,
#  'rating_count': 65957119,
#  'Updated': '2019-04-23',
#  'Size': 'Varies with device',
#  'Installs': 1000000000,
#  'Current Version': 'Varies with device',
#  'Requires Android': 'Varies with device',
#  'Interactive Elements': 'Users Interact, Shares Location, Digital Purchases',
#  'In-app Products': '$0.99 - $399.99 per item'}

# %%
# finally change the key names of things as following
# save to D2
mapping = {
    'Updated': 'update_time',
    'Size': 'size',
    'Installs': 'min_install', # because we got rid of the + sign
    'Current Version': 'version',
    'Requires Android': 'android_version',
    'Interactive Elements': 'interactive_elements',
    'In-app Products': 'in_app_products',
}

D2 = dict()
for pkg in D1:
    j = D1[pkg]
    nj = dict()
    for key in j:
        if key in mapping:
            nj[mapping[key]] = j[key]
        else:
            nj[key] = j[key]
    D2[pkg] = nj

# %%
D2['com.facebook.orca']
# Out:
# {'name': 'Messenger – Text and Video Chat for Free',
#  'pkg': 'com.facebook.orca',
#  'publisher': 'Facebook',
#  'genres': 'Communication',
#  'content_ratings': 'Everyone',
#  'is_editor_choice': True,
#  'price': 0.0,
#  'inapp_details': 'Offers in-app purchases',
#  'has_video': False,
#  'num_screenshot': 8,
#  'rating_overall': 4.1,
#  'rating_5': 40250992,
#  'rating_4': 9365883,
#  'rating_3': 6007039,
#  'rating_2': 2502559,
#  'rating_1': 7830646,
#  'rating_count': 65957119,
#  'update_time': '2019-04-23',
#  'size': 'Varies with device',
#  'min_install': 1000000000,
#  'version': 'Varies with device',
#  'android_version': 'Varies with device',
#  'interactive_elements': 'Users Interact, Shares Location, Digital Purchases',
#  'in_app_products': '$0.99 - $399.99 per item'}

# %%
D2['com.mojang.minecraftpe']
# Out:
# {'name': 'Minecraft',
#  'pkg': 'com.mojang.minecraftpe',
#  'publisher': 'Mojang',
#  'genres': 'Arcade',
#  'content_ratings': 'Everyone 10+',
#  'is_editor_choice': True,
#  'price': 6.99,
#  'inapp_details': 'Offers in-app purchases',
#  'has_video': True,
#  'num_screenshot': 23,
#  'rating_overall': 4.5,
#  'rating_5': 2088955,
#  'rating_4': 243506,
#  'rating_3': 119376,
#  'rating_2': 58057,
#  'rating_1': 167167,
#  'rating_count': 2677061,
#  'update_time': '2019-04-23',
#  'size': 'Varies with device',
#  'min_install': 10000000,
#  'version': '1.11.0.23',
#  'android_version': '4.2 and up',
#  'interactive_elements': 'Users Interact',
#  'in_app_products': '$0.99 - $49.99 per item'}

# %%
df = pd.DataFrame.from_dict(D2, orient='index')
df
# Out:
#                                                                                               name  \
# Air.Density                                                                 Air Density Calculator
# Air.Lite                                                              Air Lite Psychrometric Calcs
# Alekseyt.Lusher                                                                        Тест Люшера
# Alfasoft.Widgets.PsychedelicAnalogClock                                          Psychedelic Clock
# Alfasoft.Widgets.SweetYorkshireAnalogClock                                   Sweet Yorkshire Clock
# AlligatorCallPackage.Pkg                                                            Alligator Call
# AmaxSoftware.bubblelevel                                                      Bubble Level (Scale)
# Andrew.Compass.com                                                                   Rapid Compass
# Android.WirelessPassword                                                    Wifi Password Recovery
# Animato.Eained                                                                             E-ained
# Appdo.test                                                                                   appdo
# ArjunArora.lordkrishnalwplwp                                           Lord Krishna Live Wallpaper
# Ashes2010_androidmkp.indvseng                                                      Ind Vs Eng 2017
# Astegiudiziarie.pck                                                               Aste Giudiziarie
# Atbs.iTpms                                                                              iTPMSystem
# AutoLoanCalculatorPRO.DPsoftware.org                                Auto Loan Calculator PRO trial
# AutoLoanCalculatorPRO_Market.DPsoftware.org                               Auto Loan Calculator PRO
# AutomateIt.mainPackage                           AutomateIt - Automate tasks, save battery and ...
# AutomateItPro.mainPackage                          AutomateIt Pro - Automate tasks on your Android
# B4A.BigFivePersonalityTest                                                  Big 5 Personality Test
# B4A.EmotionalIntelligenceTest2                                         Emotional Intelligence Test
# BSH.SmartHouseSystem                                                 BSH SmartHouse Remote Control
# BacteriologiaFree.Doctor                                                Preguntas de Bacteriologia
# BlackProject.HouseSpeechDemo                                              Relay Speech Recognition
# BlueFRom.Consult                                                                          BlueFRom
# BnpParibas.Derivative.Mobile.App.Android.Dailys                                       Trader's Box
# CP.iCarCheck                                                                     Instant Car Check
# Cam.SILENT                                                           Uva Silent Widget Camera Free
# Cam_P.SILENT                                                          Uva Silent Widget Camera Pro
# ChaosSoftware.LakeLevel                                                          Texas Lake Levels
# ...                                                                                            ...
# zw.co.tengai                                                              Ownai Online Marketplace
# zw.co.vokers.perfectuninstaller                                                Perfect Uninstaller
# zw.co.zb.mobileapp                                                               ZB Mobile Banking
# zw.co.zbcradio.app.classicfm                                                     Classic 263 Radio
# zw.co.zbcradio.app.nationalfm                                                 National FM Zimbabwe
# zw.co.zimlaws.Zimbabwe_Laws_App                                                  Zimbabwe Laws App
# zw.gov.parlzim                                                              Parliament of Zimbabwe
# zw.gov.psc                                                                                 PSC ZIM
# zwartapps.recordsmessi_cristiano                                                Messi VS Cristiano
# zwskin.raypho.mozino                                                          Mozino - Zooper Skin
# zwskin.razerblue                                                                  Zooper Widget S5
# zwskin.temp1                                                                   Zooper Widget Razer
# zwskin.temp2                                                                    Zooper Widget 2018
# zxc.com.bpdwdvr                                                         Blaupunkt Dash Cam Control
# zy.personalitytest2                                                         Personality Test By ZY
# zy.quzhengbao.avs                                                                       WitnessCam
# zy.quzhengbao.viewer                                                                 WitnessViewer
# zyberph.hackbar.zk                                                                   Andro Hackbar
# zyloxtech.com.shayariapp                                                     Best Shayari App 2019
# zyna.sudoku.logic                                                                           Sudoku
# zyra.kayle                                                                           Speed Gun Mph
# zz.android.smartbirds                                                                   SmartBirds
# zzs.notisysinfo                                                                   NotiSysinfo Lite
# zzs.notisysinfo.pro                                                                NotiSysinfo Pro
# zzsino.com.wifi.smartsocket                                                              AI Socket
# zzy.heartEN                                                                             SweetHeart
# zzyzx.app.TheHole2                                         Room Escape game：The hole2 -stone room-
# zzyzx.app.muon                                                                         脱出×和風ホラー：夢怨
# zzyzx.co.thaiexternalkeyboard                                               Thai External Keyboard
# zzz1zzz.tracktime                                                                     Time Tracker
#
#                                                                                              pkg  \
# Air.Density                                                                          Air.Density
# Air.Lite                                                                                Air.Lite
# Alekseyt.Lusher                                                                  Alekseyt.Lusher
# Alfasoft.Widgets.PsychedelicAnalogClock                  Alfasoft.Widgets.PsychedelicAnalogClock
# Alfasoft.Widgets.SweetYorkshireAnalogClock            Alfasoft.Widgets.SweetYorkshireAnalogClock
# AlligatorCallPackage.Pkg                                                AlligatorCallPackage.Pkg
# AmaxSoftware.bubblelevel                                                AmaxSoftware.bubblelevel
# Andrew.Compass.com                                                            Andrew.Compass.com
# Android.WirelessPassword                                                Android.WirelessPassword
# Animato.Eained                                                                    Animato.Eained
# Appdo.test                                                                            Appdo.test
# ArjunArora.lordkrishnalwplwp                                        ArjunArora.lordkrishnalwplwp
# Ashes2010_androidmkp.indvseng                                      Ashes2010_androidmkp.indvseng
# Astegiudiziarie.pck                                                          Astegiudiziarie.pck
# Atbs.iTpms                                                                            Atbs.iTpms
# AutoLoanCalculatorPRO.DPsoftware.org                        AutoLoanCalculatorPRO.DPsoftware.org
# AutoLoanCalculatorPRO_Market.DPsoftware.org          AutoLoanCalculatorPRO_Market.DPsoftware.org
# AutomateIt.mainPackage                                                    AutomateIt.mainPackage
# AutomateItPro.mainPackage                                              AutomateItPro.mainPackage
# B4A.BigFivePersonalityTest                                            B4A.BigFivePersonalityTest
# B4A.EmotionalIntelligenceTest2                                    B4A.EmotionalIntelligenceTest2
# BSH.SmartHouseSystem                                                        BSH.SmartHouseSystem
# BacteriologiaFree.Doctor                                                BacteriologiaFree.Doctor
# BlackProject.HouseSpeechDemo                                        BlackProject.HouseSpeechDemo
# BlueFRom.Consult                                                                BlueFRom.Consult
# BnpParibas.Derivative.Mobile.App.Android.Dailys  BnpParibas.Derivative.Mobile.App.Android.Dailys
# CP.iCarCheck                                                                        CP.iCarCheck
# Cam.SILENT                                                                            Cam.SILENT
# Cam_P.SILENT                                                                        Cam_P.SILENT
# ChaosSoftware.LakeLevel                                                  ChaosSoftware.LakeLevel
# ...                                                                                          ...
# zw.co.tengai                                                                        zw.co.tengai
# zw.co.vokers.perfectuninstaller                                  zw.co.vokers.perfectuninstaller
# zw.co.zb.mobileapp                                                            zw.co.zb.mobileapp
# zw.co.zbcradio.app.classicfm                                        zw.co.zbcradio.app.classicfm
# zw.co.zbcradio.app.nationalfm                                      zw.co.zbcradio.app.nationalfm
# zw.co.zimlaws.Zimbabwe_Laws_App                                  zw.co.zimlaws.Zimbabwe_Laws_App
# zw.gov.parlzim                                                                    zw.gov.parlzim
# zw.gov.psc                                                                            zw.gov.psc
# zwartapps.recordsmessi_cristiano                                zwartapps.recordsmessi_cristiano
# zwskin.raypho.mozino                                                        zwskin.raypho.mozino
# zwskin.razerblue                                                                zwskin.razerblue
# zwskin.temp1                                                                        zwskin.temp1
# zwskin.temp2                                                                        zwskin.temp2
# zxc.com.bpdwdvr                                                                  zxc.com.bpdwdvr
# zy.personalitytest2                                                          zy.personalitytest2
# zy.quzhengbao.avs                                                              zy.quzhengbao.avs
# zy.quzhengbao.viewer                                                        zy.quzhengbao.viewer
# zyberph.hackbar.zk                                                            zyberph.hackbar.zk
# zyloxtech.com.shayariapp                                                zyloxtech.com.shayariapp
# zyna.sudoku.logic                                                              zyna.sudoku.logic
# zyra.kayle                                                                            zyra.kayle
# zz.android.smartbirds                                                      zz.android.smartbirds
# zzs.notisysinfo                                                                  zzs.notisysinfo
# zzs.notisysinfo.pro                                                          zzs.notisysinfo.pro
# zzsino.com.wifi.smartsocket                                          zzsino.com.wifi.smartsocket
# zzy.heartEN                                                                          zzy.heartEN
# zzyzx.app.TheHole2                                                            zzyzx.app.TheHole2
# zzyzx.app.muon                                                                    zzyzx.app.muon
# zzyzx.co.thaiexternalkeyboard                                      zzyzx.co.thaiexternalkeyboard
# zzz1zzz.tracktime                                                              zzz1zzz.tracktime
#
#                                                                           publisher  \
# Air.Density                                                              DeNysschen
# Air.Lite                                            Cold Means Mobile Software, LLC
# Alekseyt.Lusher                                                            Alekseyt
# Alfasoft.Widgets.PsychedelicAnalogClock                                    Alfasoft
# Alfasoft.Widgets.SweetYorkshireAnalogClock                                 Alfasoft
# AlligatorCallPackage.Pkg                                                 FolsomApps
# AmaxSoftware.bubblelevel                                                    LeXus22
# Andrew.Compass.com                                              Andrew Android Apps
# Android.WirelessPassword                                             Osama Abukmail
# Animato.Eained                                                              Animato
# Appdo.test                                                                    appdo
# ArjunArora.lordkrishnalwplwp                                            Arjun Arora
# Ashes2010_androidmkp.indvseng                           Zapak Mobile Games Pvt. Ltd
# Astegiudiziarie.pck                                                     Inlinea Srl
# Atbs.iTpms                                                      ATBS Technology Co.
# AutoLoanCalculatorPRO.DPsoftware.org                                  Davide Perini
# AutoLoanCalculatorPRO_Market.DPsoftware.org                           Davide Perini
# AutomateIt.mainPackage                                              SmarterApps Ltd
# AutomateItPro.mainPackage                                           SmarterApps Ltd
# B4A.BigFivePersonalityTest                                  MySkillsProfile Limited
# B4A.EmotionalIntelligenceTest2                              MySkillsProfile Limited
# BSH.SmartHouseSystem                                                    BSH-Systems
# BacteriologiaFree.Doctor                                              FreeTheDoctor
# BlackProject.HouseSpeechDemo                                         Progetti HW SW
# BlueFRom.Consult                                                             Vasily
# BnpParibas.Derivative.Mobile.App.Android.Dailys                         BNP Paribas
# CP.iCarCheck                                                                cap hpi
# Cam.SILENT                                                                  UvaSoft
# Cam_P.SILENT                                                                UvaSoft
# ChaosSoftware.LakeLevel                                  Chaos Software Group, Inc.
# ...                                                                             ...
# zw.co.tengai                                                       Cassava Smartech
# zw.co.vokers.perfectuninstaller                                              VOKERS
# zw.co.zb.mobileapp                                                          Zim App
# zw.co.zbcradio.app.classicfm                                                    ZBC
# zw.co.zbcradio.app.nationalfm                                                   ZBC
# zw.co.zimlaws.Zimbabwe_Laws_App                     Human Rights Education Movement
# zw.gov.parlzim                                                     Webdev (Pvt) LTD
# zw.gov.psc                                       Public Service Commission Zimbabwe
# zwartapps.recordsmessi_cristiano                                         Zwart Apps
# zwskin.raypho.mozino                                                   RayphoDesign
# zwskin.razerblue                                                         blue brain
# zwskin.temp1                                                             blue brain
# zwskin.temp2                                                             blue brain
# zxc.com.bpdwdvr                                                           Smart Cam
# zy.personalitytest2                                                   Yeo Zhen Yuan
# zy.quzhengbao.avs                                                            ichano
# zy.quzhengbao.viewer                                                         ichano
# zyberph.hackbar.zk                                               Zyberph Developers
# zyloxtech.com.shayariapp                                               SFV Infotech
# zyna.sudoku.logic                                                              Zyna
# zyra.kayle                                                                  Seabest
# zz.android.smartbirds                                      БДЗП / BirdLife България
# zzs.notisysinfo                                                              zsoltz
# zzs.notisysinfo.pro                                                          zsoltz
# zzsino.com.wifi.smartsocket                                                    FSRK
# zzy.heartEN                                                           CatCap Studio
# zzyzx.app.TheHole2                                                       ザイザックス株式会社
# zzyzx.app.muon                                                           ザイザックス株式会社
# zzyzx.co.thaiexternalkeyboard                                                 Zzyzx
# zzz1zzz.tracktime                                                       zafer ertas
#
#                                                                   genres  \
# Air.Density                                            Books & Reference
# Air.Lite                                                    Productivity
# Alekseyt.Lusher                                            Entertainment
# Alfasoft.Widgets.PsychedelicAnalogClock                  Personalization
# Alfasoft.Widgets.SweetYorkshireAnalogClock               Personalization
# AlligatorCallPackage.Pkg                                          Sports
# AmaxSoftware.bubblelevel                                           Tools
# Andrew.Compass.com                                                 Tools
# Android.WirelessPassword                                           Tools
# Animato.Eained                                         Books & Reference
# Appdo.test                                                         Tools
# ArjunArora.lordkrishnalwplwp                                      Social
# Ashes2010_androidmkp.indvseng                                     Sports
# Astegiudiziarie.pck                                     News & Magazines
# Atbs.iTpms                                             Maps & Navigation
# AutoLoanCalculatorPRO.DPsoftware.org                             Finance
# AutoLoanCalculatorPRO_Market.DPsoftware.org                      Finance
# AutomateIt.mainPackage                                      Productivity
# AutomateItPro.mainPackage                                   Productivity
# B4A.BigFivePersonalityTest                                     Education
# B4A.EmotionalIntelligenceTest2                                 Education
# BSH.SmartHouseSystem                                       Entertainment
# BacteriologiaFree.Doctor                                         Medical
# BlackProject.HouseSpeechDemo                                   Lifestyle
# BlueFRom.Consult                                       Maps & Navigation
# BnpParibas.Derivative.Mobile.App.Android.Dailys                  Finance
# CP.iCarCheck                                                       Tools
# Cam.SILENT                                       Video Players & Editors
# Cam_P.SILENT                                     Video Players & Editors
# ChaosSoftware.LakeLevel                                   Travel & Local
# ...                                                                  ...
# zw.co.tengai                                                    Shopping
# zw.co.vokers.perfectuninstaller                             Productivity
# zw.co.zb.mobileapp                                               Finance
# zw.co.zbcradio.app.classicfm                               Entertainment
# zw.co.zbcradio.app.nationalfm                              Entertainment
# zw.co.zimlaws.Zimbabwe_Laws_App                             Productivity
# zw.gov.parlzim                                                    Social
# zw.gov.psc                                                 Communication
# zwartapps.recordsmessi_cristiano                                  Sports
# zwskin.raypho.mozino                                     Personalization
# zwskin.razerblue                                         Personalization
# zwskin.temp1                                             Personalization
# zwskin.temp2                                                   Lifestyle
# zxc.com.bpdwdvr                                              Photography
# zy.personalitytest2                                            Lifestyle
# zy.quzhengbao.avs                                                  Tools
# zy.quzhengbao.viewer                                               Tools
# zyberph.hackbar.zk                                                 Tools
# zyloxtech.com.shayariapp                                   Entertainment
# zyna.sudoku.logic                                                 Puzzle
# zyra.kayle                                                         Tools
# zz.android.smartbirds                                          Education
# zzs.notisysinfo                                                    Tools
# zzs.notisysinfo.pro                                                Tools
# zzsino.com.wifi.smartsocket                                        Tools
# zzy.heartEN                                                 Role Playing
# zzyzx.app.TheHole2                                             Adventure
# zzyzx.app.muon                                                 Adventure
# zzyzx.co.thaiexternalkeyboard                                      Tools
# zzz1zzz.tracktime                                           Productivity
#
#                                                 content_ratings  \
# Air.Density                                            Everyone
# Air.Lite                                               Everyone
# Alekseyt.Lusher                                        Everyone
# Alfasoft.Widgets.PsychedelicAnalogClock                Everyone
# Alfasoft.Widgets.SweetYorkshireAnalogClock             Everyone
# AlligatorCallPackage.Pkg                               Everyone
# AmaxSoftware.bubblelevel                               Everyone
# Andrew.Compass.com                                     Everyone
# Android.WirelessPassword                               Everyone
# Animato.Eained                                         Everyone
# Appdo.test                                             Everyone
# ArjunArora.lordkrishnalwplwp                           Everyone
# Ashes2010_androidmkp.indvseng                          Everyone
# Astegiudiziarie.pck                                    Everyone
# Atbs.iTpms                                             Everyone
# AutoLoanCalculatorPRO.DPsoftware.org                   Everyone
# AutoLoanCalculatorPRO_Market.DPsoftware.org            Everyone
# AutomateIt.mainPackage                                 Everyone
# AutomateItPro.mainPackage                              Everyone
# B4A.BigFivePersonalityTest                             Everyone
# B4A.EmotionalIntelligenceTest2                         Everyone
# BSH.SmartHouseSystem                                   Everyone
# BacteriologiaFree.Doctor                               Everyone
# BlackProject.HouseSpeechDemo                           Everyone
# BlueFRom.Consult                                       Everyone
# BnpParibas.Derivative.Mobile.App.Android.Dailys        Everyone
# CP.iCarCheck                                           Everyone
# Cam.SILENT                                             Everyone
# Cam_P.SILENT                                           Everyone
# ChaosSoftware.LakeLevel                                Everyone
# ...                                                         ...
# zw.co.tengai                                           Everyone
# zw.co.vokers.perfectuninstaller                        Everyone
# zw.co.zb.mobileapp                                     Everyone
# zw.co.zbcradio.app.classicfm                           Everyone
# zw.co.zbcradio.app.nationalfm                          Everyone
# zw.co.zimlaws.Zimbabwe_Laws_App                        Everyone
# zw.gov.parlzim                                         Everyone
# zw.gov.psc                                             Everyone
# zwartapps.recordsmessi_cristiano                       Everyone
# zwskin.raypho.mozino                                   Everyone
# zwskin.razerblue                                       Everyone
# zwskin.temp1                                           Everyone
# zwskin.temp2                                           Everyone
# zxc.com.bpdwdvr                                        Everyone
# zy.personalitytest2                                    Everyone
# zy.quzhengbao.avs                                      Everyone
# zy.quzhengbao.viewer                                   Everyone
# zyberph.hackbar.zk                                     Everyone
# zyloxtech.com.shayariapp                                   Teen
# zyna.sudoku.logic                                      Everyone
# zyra.kayle                                             Everyone
# zz.android.smartbirds                                  Everyone
# zzs.notisysinfo                                        Everyone
# zzs.notisysinfo.pro                                    Everyone
# zzsino.com.wifi.smartsocket                            Everyone
# zzy.heartEN                                                Teen
# zzyzx.app.TheHole2                                     Everyone
# zzyzx.app.muon                                             Teen
# zzyzx.co.thaiexternalkeyboard                          Everyone
# zzz1zzz.tracktime                                      Everyone
#
#                                                  is_editor_choice  price  \
# Air.Density                                                 False   0.00
# Air.Lite                                                    False   0.00
# Alekseyt.Lusher                                             False   0.00
# Alfasoft.Widgets.PsychedelicAnalogClock                     False   0.00
# Alfasoft.Widgets.SweetYorkshireAnalogClock                  False   0.00
# AlligatorCallPackage.Pkg                                    False   0.99
# AmaxSoftware.bubblelevel                                    False   0.00
# Andrew.Compass.com                                          False   0.00
# Android.WirelessPassword                                    False   0.00
# Animato.Eained                                              False   0.00
# Appdo.test                                                  False   0.00
# ArjunArora.lordkrishnalwplwp                                False   0.00
# Ashes2010_androidmkp.indvseng                               False   0.00
# Astegiudiziarie.pck                                         False   0.00
# Atbs.iTpms                                                  False   0.00
# AutoLoanCalculatorPRO.DPsoftware.org                        False   0.00
# AutoLoanCalculatorPRO_Market.DPsoftware.org                 False   1.49
# AutomateIt.mainPackage                                      False   0.00
# AutomateItPro.mainPackage                                   False   2.99
# B4A.BigFivePersonalityTest                                  False   0.00
# B4A.EmotionalIntelligenceTest2                              False   0.00
# BSH.SmartHouseSystem                                        False   0.00
# BacteriologiaFree.Doctor                                    False   0.00
# BlackProject.HouseSpeechDemo                                False   0.00
# BlueFRom.Consult                                            False   0.00
# BnpParibas.Derivative.Mobile.App.Android.Dailys             False   0.00
# CP.iCarCheck                                                False   0.00
# Cam.SILENT                                                  False   0.00
# Cam_P.SILENT                                                False   2.49
# ChaosSoftware.LakeLevel                                     False   0.00
# ...                                                           ...    ...
# zw.co.tengai                                                False   0.00
# zw.co.vokers.perfectuninstaller                             False   0.00
# zw.co.zb.mobileapp                                          False   0.00
# zw.co.zbcradio.app.classicfm                                False   0.00
# zw.co.zbcradio.app.nationalfm                               False   0.00
# zw.co.zimlaws.Zimbabwe_Laws_App                             False   0.00
# zw.gov.parlzim                                              False   0.00
# zw.gov.psc                                                  False   0.00
# zwartapps.recordsmessi_cristiano                            False   0.00
# zwskin.raypho.mozino                                        False   0.00
# zwskin.razerblue                                            False   3.99
# zwskin.temp1                                                False   5.12
# zwskin.temp2                                                False   4.49
# zxc.com.bpdwdvr                                             False   0.00
# zy.personalitytest2                                         False   0.00
# zy.quzhengbao.avs                                           False   0.00
# zy.quzhengbao.viewer                                        False   0.00
# zyberph.hackbar.zk                                          False   0.00
# zyloxtech.com.shayariapp                                    False   0.00
# zyna.sudoku.logic                                           False   0.00
# zyra.kayle                                                  False   0.00
# zz.android.smartbirds                                       False   0.00
# zzs.notisysinfo                                             False   0.00
# zzs.notisysinfo.pro                                         False   1.99
# zzsino.com.wifi.smartsocket                                 False   0.00
# zzy.heartEN                                                 False   0.00
# zzyzx.app.TheHole2                                          False   0.00
# zzyzx.app.muon                                              False   0.00
# zzyzx.co.thaiexternalkeyboard                               False   0.00
# zzz1zzz.tracktime                                           False   0.00
#
#                                                                         inapp_details  \
# Air.Density                                                                      null
# Air.Lite                                                                 Contains Ads
# Alekseyt.Lusher                                                          Contains Ads
# Alfasoft.Widgets.PsychedelicAnalogClock                                          null
# Alfasoft.Widgets.SweetYorkshireAnalogClock                                       null
# AlligatorCallPackage.Pkg                                                         null
# AmaxSoftware.bubblelevel                                                         null
# Andrew.Compass.com                                                               null
# Android.WirelessPassword                                                 Contains Ads
# Animato.Eained                                                           Contains Ads
# Appdo.test                                                                       null
# ArjunArora.lordkrishnalwplwp                                                     null
# Ashes2010_androidmkp.indvseng                                                    null
# Astegiudiziarie.pck                                                              null
# Atbs.iTpms                                                                       null
# AutoLoanCalculatorPRO.DPsoftware.org                                             null
# AutoLoanCalculatorPRO_Market.DPsoftware.org                                      null
# AutomateIt.mainPackage                           Contains Ads·Offers in-app purchases
# AutomateItPro.mainPackage                                                        null
# B4A.BigFivePersonalityTest                                               Contains Ads
# B4A.EmotionalIntelligenceTest2                                           Contains Ads
# BSH.SmartHouseSystem                                                             null
# BacteriologiaFree.Doctor                                                 Contains Ads
# BlackProject.HouseSpeechDemo                                                     null
# BlueFRom.Consult                                                                 null
# BnpParibas.Derivative.Mobile.App.Android.Dailys                                  null
# CP.iCarCheck                                                  Offers in-app purchases
# Cam.SILENT                                                                       null
# Cam_P.SILENT                                                                     null
# ChaosSoftware.LakeLevel                                                          null
# ...                                                                               ...
# zw.co.tengai                                                                     null
# zw.co.vokers.perfectuninstaller                                          Contains Ads
# zw.co.zb.mobileapp                                                               null
# zw.co.zbcradio.app.classicfm                                                     null
# zw.co.zbcradio.app.nationalfm                                                    null
# zw.co.zimlaws.Zimbabwe_Laws_App                                                  null
# zw.gov.parlzim                                                                   null
# zw.gov.psc                                                                       null
# zwartapps.recordsmessi_cristiano                                         Contains Ads
# zwskin.raypho.mozino                                                             null
# zwskin.razerblue                                                                 null
# zwskin.temp1                                                                     null
# zwskin.temp2                                                                     null
# zxc.com.bpdwdvr                                                                  null
# zy.personalitytest2                                                              null
# zy.quzhengbao.avs                                Contains Ads·Offers in-app purchases
# zy.quzhengbao.viewer                                                             null
# zyberph.hackbar.zk                                                       Contains Ads
# zyloxtech.com.shayariapp                                                 Contains Ads
# zyna.sudoku.logic                                                        Contains Ads
# zyra.kayle                                                               Contains Ads
# zz.android.smartbirds                                                            null
# zzs.notisysinfo                                                                  null
# zzs.notisysinfo.pro                                                              null
# zzsino.com.wifi.smartsocket                                                      null
# zzy.heartEN                                      Contains Ads·Offers in-app purchases
# zzyzx.app.TheHole2                                                       Contains Ads
# zzyzx.app.muon                                   Contains Ads·Offers in-app purchases
# zzyzx.co.thaiexternalkeyboard                                                    null
# zzz1zzz.tracktime                                Contains Ads·Offers in-app purchases
#
#                                                  has_video  num_screenshot  \
# Air.Density                                          False               2
# Air.Lite                                             False               4
# Alekseyt.Lusher                                      False               3
# Alfasoft.Widgets.PsychedelicAnalogClock              False               2
# Alfasoft.Widgets.SweetYorkshireAnalogClock           False               2
# AlligatorCallPackage.Pkg                             False               2
# AmaxSoftware.bubblelevel                             False               3
# Andrew.Compass.com                                    True               8
# Android.WirelessPassword                             False               4
# Animato.Eained                                       False               3
# Appdo.test                                            True               3
# ArjunArora.lordkrishnalwplwp                         False               2
# Ashes2010_androidmkp.indvseng                        False              10
# Astegiudiziarie.pck                                  False              14
# Atbs.iTpms                                           False               9
# AutoLoanCalculatorPRO.DPsoftware.org                  True              21
# AutoLoanCalculatorPRO_Market.DPsoftware.org           True              21
# AutomateIt.mainPackage                                True              10
# AutomateItPro.mainPackage                             True              10
# B4A.BigFivePersonalityTest                           False               6
# B4A.EmotionalIntelligenceTest2                       False               5
# BSH.SmartHouseSystem                                  True               4
# BacteriologiaFree.Doctor                             False               5
# BlackProject.HouseSpeechDemo                          True               3
# BlueFRom.Consult                                      True               4
# BnpParibas.Derivative.Mobile.App.Android.Dailys      False               7
# CP.iCarCheck                                         False              15
# Cam.SILENT                                           False               3
# Cam_P.SILENT                                         False               4
# ChaosSoftware.LakeLevel                              False               2
# ...                                                    ...             ...
# zw.co.tengai                                         False               8
# zw.co.vokers.perfectuninstaller                      False               6
# zw.co.zb.mobileapp                                   False               8
# zw.co.zbcradio.app.classicfm                         False               2
# zw.co.zbcradio.app.nationalfm                        False               3
# zw.co.zimlaws.Zimbabwe_Laws_App                      False               8
# zw.gov.parlzim                                       False               8
# zw.gov.psc                                           False               5
# zwartapps.recordsmessi_cristiano                     False               7
# zwskin.raypho.mozino                                 False               4
# zwskin.razerblue                                     False               2
# zwskin.temp1                                         False              12
# zwskin.temp2                                         False              15
# zxc.com.bpdwdvr                                      False               4
# zy.personalitytest2                                  False              15
# zy.quzhengbao.avs                                    False               4
# zy.quzhengbao.viewer                                 False               3
# zyberph.hackbar.zk                                   False               8
# zyloxtech.com.shayariapp                             False               8
# zyna.sudoku.logic                                    False               4
# zyra.kayle                                           False               9
# zz.android.smartbirds                                False              16
# zzs.notisysinfo                                      False              10
# zzs.notisysinfo.pro                                  False              12
# zzsino.com.wifi.smartsocket                          False               6
# zzy.heartEN                                          False              12
# zzyzx.app.TheHole2                                   False              15
# zzyzx.app.muon                                        True              16
# zzyzx.co.thaiexternalkeyboard                        False               2
# zzz1zzz.tracktime                                    False               9
#
#                                                  ...  rating_2  rating_1  \
# Air.Density                                      ...         0         2
# Air.Lite                                         ...        17        28
# Alekseyt.Lusher                                  ...       304       794
# Alfasoft.Widgets.PsychedelicAnalogClock          ...        28        59
# Alfasoft.Widgets.SweetYorkshireAnalogClock       ...        11        53
# AlligatorCallPackage.Pkg                         ...         0         1
# AmaxSoftware.bubblelevel                         ...         1         3
# Andrew.Compass.com                               ...        97       368
# Android.WirelessPassword                         ...       138       954
# Animato.Eained                                   ...        26        29
# Appdo.test                                       ...         0         2
# ArjunArora.lordkrishnalwplwp                     ...        16        22
# Ashes2010_androidmkp.indvseng                    ...       124       355
# Astegiudiziarie.pck                              ...        94       374
# Atbs.iTpms                                       ...         2        22
# AutoLoanCalculatorPRO.DPsoftware.org             ...         0        18
# AutoLoanCalculatorPRO_Market.DPsoftware.org      ...         0         0
# AutomateIt.mainPackage                           ...       717      1060
# AutomateItPro.mainPackage                        ...       368       545
# B4A.BigFivePersonalityTest                       ...       543      1498
# B4A.EmotionalIntelligenceTest2                   ...        21        31
# BSH.SmartHouseSystem                             ...         0         8
# BacteriologiaFree.Doctor                         ...         7        14
# BlackProject.HouseSpeechDemo                     ...         1         1
# BlueFRom.Consult                                 ...         7        20
# BnpParibas.Derivative.Mobile.App.Android.Dailys  ...        25        61
# CP.iCarCheck                                     ...        69       315
# Cam.SILENT                                       ...       461      1112
# Cam_P.SILENT                                     ...        35        63
# ChaosSoftware.LakeLevel                          ...         9        13
# ...                                              ...       ...       ...
# zw.co.tengai                                     ...         1         5
# zw.co.vokers.perfectuninstaller                  ...         0         1
# zw.co.zb.mobileapp                               ...         2        12
# zw.co.zbcradio.app.classicfm                     ...         0         0
# zw.co.zbcradio.app.nationalfm                    ...         3         8
# zw.co.zimlaws.Zimbabwe_Laws_App                  ...         0         0
# zw.gov.parlzim                                   ...         2         5
# zw.gov.psc                                       ...         1         0
# zwartapps.recordsmessi_cristiano                 ...        32        96
# zwskin.raypho.mozino                             ...         0         0
# zwskin.razerblue                                 ...         0         2
# zwskin.temp1                                     ...         3        18
# zwskin.temp2                                     ...         0         2
# zxc.com.bpdwdvr                                  ...         2         5
# zy.personalitytest2                              ...         3         4
# zy.quzhengbao.avs                                ...         5         6
# zy.quzhengbao.viewer                             ...         0         1
# zyberph.hackbar.zk                               ...        12        31
# zyloxtech.com.shayariapp                         ...         1         3
# zyna.sudoku.logic                                ...         0         0
# zyra.kayle                                       ...         1        10
# zz.android.smartbirds                            ...         4        13
# zzs.notisysinfo                                  ...        18        28
# zzs.notisysinfo.pro                              ...         1         7
# zzsino.com.wifi.smartsocket                      ...        11        18
# zzy.heartEN                                      ...      1168      2423
# zzyzx.app.TheHole2                               ...         9         7
# zzyzx.app.muon                                   ...        33        36
# zzyzx.co.thaiexternalkeyboard                    ...         1        14
# zzz1zzz.tracktime                                ...        15        31
#
#                                                  rating_count  update_time  \
# Air.Density                                                 6   2012-04-29
# Air.Lite                                                  390   2014-06-17
# Alekseyt.Lusher                                          8190   2015-01-24
# Alfasoft.Widgets.PsychedelicAnalogClock                   416   2014-01-09
# Alfasoft.Widgets.SweetYorkshireAnalogClock                285   2014-01-18
# AlligatorCallPackage.Pkg                                    7   2011-01-26
# AmaxSoftware.bubblelevel                                   19   2012-01-23
# Andrew.Compass.com                                       1720   2013-11-15
# Android.WirelessPassword                                 3760   2017-12-07
# Animato.Eained                                            550   2012-09-02
# Appdo.test                                                  9   2012-01-11
# ArjunArora.lordkrishnalwplwp                              361   2012-10-26
# Ashes2010_androidmkp.indvseng                            2630   2018-02-28
# Astegiudiziarie.pck                                      1254   2019-02-01
# Atbs.iTpms                                                 74   2017-06-15
# AutoLoanCalculatorPRO.DPsoftware.org                       28   2019-02-22
# AutoLoanCalculatorPRO_Market.DPsoftware.org                 3   2018-12-01
# ...
# zwskin.raypho.mozino                                            1.0
# zwskin.razerblue                                               1.02
# zwskin.temp1                                                    1.5
# zwskin.temp2                                                   1.03
# zxc.com.bpdwdvr                                              1.2.09
# zy.personalitytest2                                             1.1
# zy.quzhengbao.avs                                          1.00.015
# zy.quzhengbao.viewer                                       1.00.016
# zyberph.hackbar.zk                                              2.9
# zyloxtech.com.shayariapp                                        2.4
# zyna.sudoku.logic                                             1.0.0
# zyra.kayle                                                      1.0
# zz.android.smartbirds                                           2.0
# zzs.notisysinfo                                               1.5.9
# zzs.notisysinfo.pro                                           1.1.9
# zzsino.com.wifi.smartsocket                                     2.9
# zzy.heartEN                                                   1.0.1
# zzyzx.app.TheHole2                                              1.0
# zzyzx.app.muon                                                  1.2
# zzyzx.co.thaiexternalkeyboard                                   1.0
# zzz1zzz.tracktime                                              2.04
#
#                                                     android_version  \
# Air.Density                                              2.0 and up
# Air.Lite                                                 2.3 and up
# Alekseyt.Lusher                                          2.1 and up
# Alfasoft.Widgets.PsychedelicAnalogClock                  1.5 and up
# Alfasoft.Widgets.SweetYorkshireAnalogClock               1.5 and up
# AlligatorCallPackage.Pkg                                 1.1 and up
# AmaxSoftware.bubblelevel                                 2.1 and up
# Andrew.Compass.com                                       2.2 and up
# Android.WirelessPassword                               4.0.3 and up
# Animato.Eained                                           1.6 and up
# Appdo.test                                               2.2 and up
# ArjunArora.lordkrishnalwplwp                             2.1 and up
# Ashes2010_androidmkp.indvseng                            1.5 and up
# Astegiudiziarie.pck                                      4.1 and up
# Atbs.iTpms                                               2.1 and up
# AutoLoanCalculatorPRO.DPsoftware.org                     4.0 and up
# AutoLoanCalculatorPRO_Market.DPsoftware.org              4.0 and up
# AutomateIt.mainPackage                                 4.0.3 and up
# AutomateItPro.mainPackage                              4.0.3 and up
# B4A.BigFivePersonalityTest                               1.6 and up
# B4A.EmotionalIntelligenceTest2                           1.6 and up
# BSH.SmartHouseSystem                                   2.3.3 and up
# BacteriologiaFree.Doctor                               4.0.3 and up
# BlackProject.HouseSpeechDemo                             1.6 and up
# BlueFRom.Consult                                 Varies with device
# BnpParibas.Derivative.Mobile.App.Android.Dailys          4.0 and up
# CP.iCarCheck                                             4.4 and up
# Cam.SILENT                                               2.1 and up
# Cam_P.SILENT                                             2.1 and up
# ChaosSoftware.LakeLevel                                  4.0 and up
# ...                                                             ...
# zw.co.tengai                                             4.3 and up
# zw.co.vokers.perfectuninstaller                        4.0.3 and up
# zw.co.zb.mobileapp                                       2.2 and up
# zw.co.zbcradio.app.classicfm                             4.2 and up
# zw.co.zbcradio.app.nationalfm                            4.2 and up
# zw.co.zimlaws.Zimbabwe_Laws_App                        2.3.3 and up
# zw.gov.parlzim                                         4.0.3 and up
# zw.gov.psc                                               4.0 and up
# zwartapps.recordsmessi_cristiano                         4.0 and up
# zwskin.raypho.mozino                                   4.0.3 and up
# zwskin.razerblue                                         1.1 and up
# zwskin.temp1                                             1.1 and up
# zwskin.temp2                                             1.1 and up
# zxc.com.bpdwdvr                                          4.2 and up
# zy.personalitytest2                                      4.0 and up
# zy.quzhengbao.avs                                        4.0 and up
# zy.quzhengbao.viewer                                     4.0 and up
# zyberph.hackbar.zk                                     2.0.1 and up
# zyloxtech.com.shayariapp                                 4.1 and up
# zyna.sudoku.logic                                        4.1 and up
# zyra.kayle                                               2.3 and up
# zz.android.smartbirds                                    4.4 and up
# zzs.notisysinfo                                          4.1 and up
# zzs.notisysinfo.pro                                      4.1 and up
# zzsino.com.wifi.smartsocket                            4.0.3 and up
# zzy.heartEN                                              2.2 and up
# zzyzx.app.TheHole2                                       4.4 and up
# zzyzx.app.muon                                           4.2 and up
# zzyzx.co.thaiexternalkeyboard                            4.4 and up
# zzz1zzz.tracktime                                        4.2 and up
#
#                                                                interactive_elements  \
# Air.Density                                                                     NaN
# Air.Lite                                                                        NaN
# Alekseyt.Lusher                                                                 NaN
# Alfasoft.Widgets.PsychedelicAnalogClock                                         NaN
# Alfasoft.Widgets.SweetYorkshireAnalogClock                                      NaN
# AlligatorCallPackage.Pkg                                                        NaN
# AmaxSoftware.bubblelevel                                                        NaN
# Andrew.Compass.com                                                              NaN
# Android.WirelessPassword                                                        NaN
# Animato.Eained                                                                  NaN
# Appdo.test                                                                      NaN
# ArjunArora.lordkrishnalwplwp                                                    NaN
# Ashes2010_androidmkp.indvseng                                                   NaN
# Astegiudiziarie.pck                                                             NaN
# Atbs.iTpms                                                                      NaN
# AutoLoanCalculatorPRO.DPsoftware.org                                 Users Interact
# AutoLoanCalculatorPRO_Market.DPsoftware.org                          Users Interact
# AutomateIt.mainPackage                            Users Interact, Digital Purchases
# AutomateItPro.mainPackage                                            Users Interact
# B4A.BigFivePersonalityTest                                                      NaN
# B4A.EmotionalIntelligenceTest2                                                  NaN
# BSH.SmartHouseSystem                                                            NaN
# BacteriologiaFree.Doctor                                                        NaN
# BlackProject.HouseSpeechDemo                                                    NaN
# BlueFRom.Consult                                                                NaN
# BnpParibas.Derivative.Mobile.App.Android.Dailys                                 NaN
# CP.iCarCheck                                                      Digital Purchases
# Cam.SILENT                                                                      NaN
# Cam_P.SILENT                                                                    NaN
# ChaosSoftware.LakeLevel                                                         NaN
# ...                                                                             ...
# zw.co.tengai                                     Shares Location, Digital Purchases
# zw.co.vokers.perfectuninstaller                                                 NaN
# zw.co.zb.mobileapp                                                              NaN
# zw.co.zbcradio.app.classicfm                                                    NaN
# zw.co.zbcradio.app.nationalfm                                                   NaN
# zw.co.zimlaws.Zimbabwe_Laws_App                                                 NaN
# zw.gov.parlzim                                                                  NaN
# zw.gov.psc                                                                      NaN
# zwartapps.recordsmessi_cristiano                                                NaN
# zwskin.raypho.mozino                                                            NaN
# zwskin.razerblue                                                                NaN
# zwskin.temp1                                                                    NaN
# zwskin.temp2                                                                    NaN
# zxc.com.bpdwdvr                                                                 NaN
# zy.personalitytest2                                                             NaN
# zy.quzhengbao.avs                                                 Digital Purchases
# zy.quzhengbao.viewer                                                            NaN
# zyberph.hackbar.zk                                            Unrestricted Internet
# zyloxtech.com.shayariapp                                             Users Interact
# zyna.sudoku.logic                                                               NaN
# zyra.kayle                                                                      NaN
# zz.android.smartbirds                                                           NaN
# zzs.notisysinfo                                                                 NaN
# zzs.notisysinfo.pro                                                             NaN
# zzsino.com.wifi.smartsocket                                                     NaN
# zzy.heartEN                                          Shares Info, Digital Purchases
# zzyzx.app.TheHole2                                                              NaN
# zzyzx.app.muon                                                                  NaN
# zzyzx.co.thaiexternalkeyboard                                                   NaN
# zzz1zzz.tracktime                                                               NaN
#
#                                                          in_app_products
# Air.Density                                                          NaN
# Air.Lite                                                             NaN
# Alekseyt.Lusher                                                      NaN
# Alfasoft.Widgets.PsychedelicAnalogClock                              NaN
# Alfasoft.Widgets.SweetYorkshireAnalogClock                           NaN
# AlligatorCallPackage.Pkg                                             NaN
# AmaxSoftware.bubblelevel                                             NaN
# Andrew.Compass.com                                                   NaN
# Android.WirelessPassword                                             NaN
# Animato.Eained                                                       NaN
# Appdo.test                                                           NaN
# ArjunArora.lordkrishnalwplwp                                         NaN
# Ashes2010_androidmkp.indvseng                                        NaN
# Astegiudiziarie.pck                                                  NaN
# Atbs.iTpms                                                           NaN
# AutoLoanCalculatorPRO.DPsoftware.org                                 NaN
# AutoLoanCalculatorPRO_Market.DPsoftware.org                          NaN
# AutomateIt.mainPackage                                    $1.99 per item
# AutomateItPro.mainPackage                                            NaN
# B4A.BigFivePersonalityTest                                           NaN
# B4A.EmotionalIntelligenceTest2                                       NaN
# BSH.SmartHouseSystem                                                 NaN
# BacteriologiaFree.Doctor                                             NaN
# BlackProject.HouseSpeechDemo                                         NaN
# BlueFRom.Consult                                                     NaN
# BnpParibas.Derivative.Mobile.App.Android.Dailys                      NaN
# CP.iCarCheck                                     $1.25 - $18.99 per item
# Cam.SILENT                                                           NaN
# Cam_P.SILENT                                                         NaN
# ChaosSoftware.LakeLevel                                              NaN
# ...                                                                  ...
# zw.co.tengai                                                         NaN
# zw.co.vokers.perfectuninstaller                                      NaN
# zw.co.zb.mobileapp                                                   NaN
# zw.co.zbcradio.app.classicfm                                         NaN
# zw.co.zbcradio.app.nationalfm                                        NaN
# zw.co.zimlaws.Zimbabwe_Laws_App                                      NaN
# zw.gov.parlzim                                                       NaN
# zw.gov.psc                                                           NaN
# zwartapps.recordsmessi_cristiano                                     NaN
# zwskin.raypho.mozino                                                 NaN
# zwskin.razerblue                                                     NaN
# zwskin.temp1                                                         NaN
# zwskin.temp2                                                         NaN
# zxc.com.bpdwdvr                                                      NaN
# zy.personalitytest2                                                  NaN
# zy.quzhengbao.avs                                $6.99 - $41.99 per item
# zy.quzhengbao.viewer                                                 NaN
# zyberph.hackbar.zk                                                   NaN
# zyloxtech.com.shayariapp                                             NaN
# zyna.sudoku.logic                                                    NaN
# zyra.kayle                                                           NaN
# zz.android.smartbirds                                                NaN
# zzs.notisysinfo                                                      NaN
# zzs.notisysinfo.pro                                                  NaN
# zzsino.com.wifi.smartsocket                                          NaN
# zzy.heartEN                                      $0.99 - $59.99 per item
# zzyzx.app.TheHole2                                                   NaN
# zzyzx.app.muon                                    $0.99 - $4.49 per item
# zzyzx.co.thaiexternalkeyboard                                        NaN
# zzz1zzz.tracktime                                 $1.99 - $4.99 per item
#
# [642744 rows x 24 columns]

# %%
df_sorted = df.sort_values(by=['rating_count'], ascending=False)
df_sorted
# Out:
#                                                                                         name  \
# com.whatsapp                                                              WhatsApp Messenger
# com.facebook.katana                                                                 Facebook
# com.instagram.android                                                              Instagram
# com.facebook.orca                                   Messenger – Text and Video Chat for Free
# com.supercell.clashofclans                                                    Clash of Clans
# com.cleanmaster.mguard                           Clean Master - Antivirus, Applock & Cleaner
# com.google.android.youtube                                                           YouTube
# com.kiloo.subwaysurf                                                          Subway Surfers
# com.supercell.clashroyale                                                       Clash Royale
# com.cleanmaster.security                   Security Master - Antivirus, VPN, AppLock, Boo...
# com.king.candycrushsaga                                                     Candy Crush Saga
# com.dts.freefireth                                                          Garena Free Fire
# com.UCMobile.intl                          UC Browser – Video Downloader, Watch Video Off...
# com.snapchat.android                                                                Snapchat
# com.qihoo.security                           360 Security - Free Antivirus, Booster, Cleaner
# com.google.android.apps.photos                                                 Google Photos
# com.miniclip.eightballpool                                                       8 Ball Pool
# com.outfit7.mytalkingtomfree                                                  My Talking Tom
# com.spotify.music                                               Spotify - Music and Podcasts
# com.tencent.ig                                                                   PUBG MOBILE
# com.android.chrome                                              Google Chrome: Fast & Secure
# com.twitter.android                                                                  Twitter
# com.bbm                                                          BBM - Free Calls & Messages
# com.viber.voip                               Viber Messenger - Messages, Group Chats & Calls
# com.nekki.shadowfight                                                         Shadow Fight 2
# com.mobile.legends                                                 Mobile Legends: Bang Bang
# com.nianticlabs.pokemongo                                                         Pokémon GO
# com.firsttouchgames.dls3                                            Dream League Soccer 2019
# jp.naver.line.android                                            LINE: Free Calls & Messages
# com.google.android.googlequicksearchbox                                               Google
# ...                                                                                      ...
# com.mobieslworld.kannadatoenglishspeaking                        Kannada to English Speaking
# io.influents.InfluentsPlatform.Influents                          Influents Engagement Cloud
# solo.guti.new                                         Online Sholo Guti with Girls (16 Bead)
# com.speedymarks.android.daily                                                          Daily
# com.gz.gzcard                                                                     iRollerbot
# com.gz.gzjttech.jintustar                                                         Jintu Star
# solutions.bns.suigasbillcalculator                                    Sui Gas Bill Estimator
# com.baentm.dekoplay                                          Live Cricket Score and Schedule
# com.gymfitnesscare.situpsworkout                                             Sit Ups Workout
# com.vhuntpvtltd.Jobs_and_Scholarship                                    Jobs and Scholarship
# com.conjugate.theme.honor10.launcher                                      Theme for Honor 10
# com.badli.free.apps.sindhi.keyboard                                    Sindhi keyboard Badli
# com.viastreaming.RadioGlobalPhilippines                             Radio Global Philippines
# com.gyaansankalp                                                               GYAAN SANKALP
# com.mobile.casumoo                                                                   Casumoo
# com.gyana.assamesenewnewspaper                              Assamese NewsPaper-Web & E-Paper
# com.gyana.hindinewnewspaper                                   Hindi News-All Hindi NewsPaper
# com.gyana.newassamesevideos                     Assamese videos-Assamese songs,comedy,movies
# io.ionic.alhuda                                                        Al Huda Tour & Travel
# next.launcher.memscape.theme.schilds                          SCHILDS Next Launcher 3D Theme
# com.mobile.bonrix.harsrecharge                                                 Hars Recharge
# com.viaboards.mobile.crowley                                                      Go Crowley
# com.mobile.app.pengg                                Pengg - Resto's, Pubs and Bars Discounts
# next.launcher.tapanifirst.theme.snow                             SNOW Next Launcher Theme 3D
# com.viaberry.vconnectsv                                              Viaberry Connect School
# com.gyanpot.LiveNewsTrend                                                    Live News Trend
# com.conietech.birdlistus                                       Bird Quick List United States
# solutions.insane.calculator                        Hide Your Secret Photos Behind Calculator
# io.ionic.HukambossSecurityApp                                                    Smart Guard
# com.rayan.usacalender                                                  USA Holidays Calendar
#
#                                                                                  pkg  \
# com.whatsapp                                                            com.whatsapp
# com.facebook.katana                                              com.facebook.katana
# com.instagram.android                                          com.instagram.android
# com.facebook.orca                                                  com.facebook.orca
# com.supercell.clashofclans                                com.supercell.clashofclans
# com.cleanmaster.mguard                                        com.cleanmaster.mguard
# com.google.android.youtube                                com.google.android.youtube
# com.kiloo.subwaysurf                                            com.kiloo.subwaysurf
# com.supercell.clashroyale                                  com.supercell.clashroyale
# com.cleanmaster.security                                    com.cleanmaster.security
# com.king.candycrushsaga                                      com.king.candycrushsaga
# com.dts.freefireth                                                com.dts.freefireth
# com.UCMobile.intl                                                  com.UCMobile.intl
# com.snapchat.android                                            com.snapchat.android
# com.qihoo.security                                                com.qihoo.security
# com.google.android.apps.photos                        com.google.android.apps.photos
# com.miniclip.eightballpool                                com.miniclip.eightballpool
# com.outfit7.mytalkingtomfree                            com.outfit7.mytalkingtomfree
# com.spotify.music                                                  com.spotify.music
# com.tencent.ig                                                        com.tencent.ig
# com.android.chrome                                                com.android.chrome
# com.twitter.android                                              com.twitter.android
# com.bbm                                                                      com.bbm
# com.viber.voip                                                        com.viber.voip
# com.nekki.shadowfight                                          com.nekki.shadowfight
# com.mobile.legends                                                com.mobile.legends
# com.nianticlabs.pokemongo                                  com.nianticlabs.pokemongo
# com.firsttouchgames.dls3                                    com.firsttouchgames.dls3
# jp.naver.line.android                                          jp.naver.line.android
# com.google.android.googlequicksearchbox      com.google.android.googlequicksearchbox
# ...                                                                              ...
# com.mobieslworld.kannadatoenglishspeaking  com.mobieslworld.kannadatoenglishspeaking
# io.influents.InfluentsPlatform.Influents    io.influents.InfluentsPlatform.Influents
# solo.guti.new                                                          solo.guti.new
# com.speedymarks.android.daily                          com.speedymarks.android.daily
# com.gz.gzcard                                                          com.gz.gzcard
# com.gz.gzjttech.jintustar                                  com.gz.gzjttech.jintustar
# solutions.bns.suigasbillcalculator                solutions.bns.suigasbillcalculator
# com.baentm.dekoplay                                              com.baentm.dekoplay
# com.gymfitnesscare.situpsworkout                    com.gymfitnesscare.situpsworkout
# com.vhuntpvtltd.Jobs_and_Scholarship            com.vhuntpvtltd.Jobs_and_Scholarship
# com.conjugate.theme.honor10.launcher            com.conjugate.theme.honor10.launcher
# com.badli.free.apps.sindhi.keyboard              com.badli.free.apps.sindhi.keyboard
# com.viastreaming.RadioGlobalPhilippines      com.viastreaming.RadioGlobalPhilippines
# com.gyaansankalp                                                    com.gyaansankalp
# com.mobile.casumoo                                                com.mobile.casumoo
# com.gyana.assamesenewnewspaper                        com.gyana.assamesenewnewspaper
# com.gyana.hindinewnewspaper                              com.gyana.hindinewnewspaper
# com.gyana.newassamesevideos                              com.gyana.newassamesevideos
# io.ionic.alhuda                                                      io.ionic.alhuda
# next.launcher.memscape.theme.schilds            next.launcher.memscape.theme.schilds
# com.mobile.bonrix.harsrecharge                        com.mobile.bonrix.harsrecharge
# com.viaboards.mobile.crowley                            com.viaboards.mobile.crowley
# com.mobile.app.pengg                                            com.mobile.app.pengg
# next.launcher.tapanifirst.theme.snow            next.launcher.tapanifirst.theme.snow
# com.viaberry.vconnectsv                                      com.viaberry.vconnectsv
# com.gyanpot.LiveNewsTrend                                  com.gyanpot.LiveNewsTrend
# com.conietech.birdlistus                                    com.conietech.birdlistus
# solutions.insane.calculator                              solutions.insane.calculator
# io.ionic.HukambossSecurityApp                          io.ionic.HukambossSecurityApp
# com.rayan.usacalender                                          com.rayan.usacalender
#
#                                                                                 publisher  \
# com.whatsapp                                                                WhatsApp Inc.
# com.facebook.katana                                                              Facebook
# com.instagram.android                                                           Instagram
# com.facebook.orca                                                                Facebook
# com.supercell.clashofclans                                                      Supercell
# com.cleanmaster.mguard                                                     Cheetah Mobile
# com.google.android.youtube                                                     Google LLC
# com.kiloo.subwaysurf                                                                Kiloo
# com.supercell.clashroyale                                                       Supercell
# com.cleanmaster.security                             Cheetah Mobile (AppLock & AntiVirus)
# com.king.candycrushsaga                                                              King
# com.dts.freefireth                                 GARENA INTERNATIONAL I PRIVATE LIMITED
# com.UCMobile.intl                                                              UCWeb Inc.
# com.snapchat.android                                                             Snap Inc
# com.qihoo.security                                            360 Mobile Security Limited
# com.google.android.apps.photos                                                 Google LLC
# com.miniclip.eightballpool                                                   Miniclip.com
# com.outfit7.mytalkingtomfree                                              Outfit7 Limited
# com.spotify.music                                                            Spotify Ltd.
# com.tencent.ig                                                              Tencent Games
# com.android.chrome                                                             Google LLC
# com.twitter.android                                                         Twitter, Inc.
# com.bbm                                                                             BBM .
# com.viber.voip                                                       Viber Media S.à r.l.
# com.nekki.shadowfight                                                               NEKKI
# com.mobile.legends                                                                Moonton
# com.nianticlabs.pokemongo                                                   Niantic, Inc.
# com.firsttouchgames.dls3                                           First Touch Games Ltd.
# jp.naver.line.android                                                    LINE Corporation
# com.google.android.googlequicksearchbox                                        Google LLC
# ...                                                                                   ...
# com.mobieslworld.kannadatoenglishspeaking                                    mobieslworld
# io.influents.InfluentsPlatform.Influents                                        Influents
# solo.guti.new                                                           Gauva and company
# com.speedymarks.android.daily                                                 SpeedyMarks
# com.gz.gzcard                                                                       logic
# com.gz.gzjttech.jintustar                                                      yuntumanbu
# solutions.bns.suigasbillcalculator                                          BNS Solutions
# com.baentm.dekoplay                                                  Bangla Entertainment
# com.gymfitnesscare.situpsworkout                                         Smooth Zym Helth
# com.vhuntpvtltd.Jobs_and_Scholarship                                       V Hunt Pvt Ltd
# com.conjugate.theme.honor10.launcher                                       Conjugate Apps
# com.badli.free.apps.sindhi.keyboard                                       Badli Free Apps
# com.viastreaming.RadioGlobalPhilippines                                  ViaStreaming.com
# com.gyaansankalp                                                             AppsEazy.com
# com.mobile.casumoo                                                          casumo Casino
# com.gyana.assamesenewnewspaper                                               gyana behera
# com.gyana.hindinewnewspaper                                                  gyana behera
# com.gyana.newassamesevideos                                                  gyana behera
# io.ionic.alhuda                                                    Softlysis Technologies
# next.launcher.memscape.theme.schilds                                           scapechild
# com.mobile.bonrix.harsrecharge                                    Bonrix Software Systems
# com.viaboards.mobile.crowley                                           Tranztec Solutions
# com.mobile.app.pengg                                                         MobileFibre.
# next.launcher.tapanifirst.theme.snow                                          tapanifirst
# com.viaberry.vconnectsv                                 Viaberry Networks Private Limited
# com.gyanpot.LiveNewsTrend                                                      iBoldMedia
# com.conietech.birdlistus                                                    Malcolm Brown
# solutions.insane.calculator                                          Insane Solutions LLC
# io.ionic.HukambossSecurityApp              HUKAMBOSS INNOVATIVE VENTURES PRIVATE LIMITED.
# com.rayan.usacalender                                                           Rayan Inc
#
#                                                             genres  \
# com.whatsapp                                         Communication
# com.facebook.katana                                         Social
# com.instagram.android                                       Social
# com.facebook.orca                                    Communication
# com.supercell.clashofclans                                Strategy
# com.cleanmaster.mguard                                       Tools
# com.google.android.youtube                 Video Players & Editors
# com.kiloo.subwaysurf                                        Arcade
# com.supercell.clashroyale                                 Strategy
# com.cleanmaster.security                                     Tools
# com.king.candycrushsaga                                     Casual
# com.dts.freefireth                                          Action
# com.UCMobile.intl                                    Communication
# com.snapchat.android                                        Social
# com.qihoo.security                                           Tools
# com.google.android.apps.photos                         Photography
# com.miniclip.eightballpool                                  Sports
# com.outfit7.mytalkingtomfree                                Casual
# com.spotify.music                                    Music & Audio
# com.tencent.ig                                              Action
# com.android.chrome                                   Communication
# com.twitter.android                               News & Magazines
# com.bbm                                              Communication
# com.viber.voip                                       Communication
# com.nekki.shadowfight                                       Action
# com.mobile.legends                                          Action
# com.nianticlabs.pokemongo                                Adventure
# com.firsttouchgames.dls3                                    Sports
# jp.naver.line.android                                Communication
# com.google.android.googlequicksearchbox                      Tools
# ...                                                            ...
# com.mobieslworld.kannadatoenglishspeaking                Education
# io.influents.InfluentsPlatform.Influents                  Business
# solo.guti.new                                                Board
# com.speedymarks.android.daily                         Productivity
# com.gz.gzcard                                          Photography
# com.gz.gzjttech.jintustar                                    Tools
# solutions.bns.suigasbillcalculator                       Lifestyle
# com.baentm.dekoplay                                         Sports
# com.gymfitnesscare.situpsworkout                  Health & Fitness
# com.vhuntpvtltd.Jobs_and_Scholarship                     Education
# com.conjugate.theme.honor10.launcher               Personalization
# com.badli.free.apps.sindhi.keyboard                          Tools
# com.viastreaming.RadioGlobalPhilippines              Music & Audio
# com.gyaansankalp                                         Education
# com.mobile.casumoo                                          Casino
# com.gyana.assamesenewnewspaper                    News & Magazines
# com.gyana.hindinewnewspaper                       News & Magazines
# com.gyana.newassamesevideos                          Entertainment
# io.ionic.alhuda                                     Travel & Local
# next.launcher.memscape.theme.schilds               Personalization
# com.mobile.bonrix.harsrecharge                            Business
# com.viaboards.mobile.crowley                       Auto & Vehicles
# com.mobile.app.pengg                                  Food & Drink
# next.launcher.tapanifirst.theme.snow                     Lifestyle
# com.viaberry.vconnectsv                                  Education
# com.gyanpot.LiveNewsTrend                            Entertainment
# com.conietech.birdlistus                                 Lifestyle
# solutions.insane.calculator                                  Tools
# io.ionic.HukambossSecurityApp                         House & Home
# com.rayan.usacalender                                       Events
#
#                                           content_ratings  is_editor_choice  \
# com.whatsapp                                     Everyone             False
# com.facebook.katana                                  Teen             False
# com.instagram.android                                Teen              True
# com.facebook.orca                                Everyone              True
# com.supercell.clashofclans                   Everyone 10+              True
# com.cleanmaster.mguard                           Everyone             False
# com.google.android.youtube                           Teen              True
# com.kiloo.subwaysurf                         Everyone 10+              True
# com.supercell.clashroyale                    Everyone 10+              True
# com.cleanmaster.security                         Everyone             False
# com.king.candycrushsaga                          Everyone             False
# com.dts.freefireth                                   Teen             False
# com.UCMobile.intl                                    Teen             False
# com.snapchat.android                                 Teen              True
# com.qihoo.security                               Everyone             False
# com.google.android.apps.photos                   Everyone             False
# com.miniclip.eightballpool                       Everyone              True
# com.outfit7.mytalkingtomfree                     Everyone             False
# com.spotify.music                                    Teen             False
# com.tencent.ig                                       Teen              True
# com.android.chrome                               Everyone             False
# com.twitter.android                            Mature 17+             False
# com.bbm                                          Everyone             False
# com.viber.voip                                   Everyone              True
# com.nekki.shadowfight                        Everyone 10+              True
# com.mobile.legends                                   Teen             False
# com.nianticlabs.pokemongo                        Everyone              True
# com.firsttouchgames.dls3                         Everyone              True
# jp.naver.line.android                            Everyone             False
# com.google.android.googlequicksearchbox          Everyone             False
# ...                                                   ...               ...
# com.mobieslworld.kannadatoenglishspeaking        Everyone             False
# io.influents.InfluentsPlatform.Influents         Everyone             False
# solo.guti.new                                    Everyone             False
# com.speedymarks.android.daily                    Everyone             False
# com.gz.gzcard                                    Everyone             False
# com.gz.gzjttech.jintustar                        Everyone             False
# solutions.bns.suigasbillcalculator               Everyone             False
# com.baentm.dekoplay                              Everyone             False
# com.gymfitnesscare.situpsworkout                 Everyone             False
# com.vhuntpvtltd.Jobs_and_Scholarship             Everyone             False
# com.conjugate.theme.honor10.launcher             Everyone             False
# com.badli.free.apps.sindhi.keyboard              Everyone             False
# com.viastreaming.RadioGlobalPhilippines          Everyone             False
# com.gyaansankalp                                 Everyone             False
# com.mobile.casumoo                                   Teen             False
# com.gyana.assamesenewnewspaper                   Everyone             False
# com.gyana.hindinewnewspaper                      Everyone             False
# com.gyana.newassamesevideos                    Mature 17+             False
# io.ionic.alhuda                                  Everyone             False
# next.launcher.memscape.theme.schilds             Everyone             False
# com.mobile.bonrix.harsrecharge                   Everyone             False
# com.viaboards.mobile.crowley                     Everyone             False
# com.mobile.app.pengg                             Everyone             False
# next.launcher.tapanifirst.theme.snow             Everyone             False
# com.viaberry.vconnectsv                          Everyone             False
# com.gyanpot.LiveNewsTrend                        Everyone             False
# com.conietech.birdlistus                         Everyone             False
# solutions.insane.calculator                      Everyone             False
# io.ionic.HukambossSecurityApp                    Everyone             False
# com.rayan.usacalender                            Everyone             False
#
#                                            price  \
# com.whatsapp                                0.00
# com.facebook.katana                         0.00
# com.instagram.android                       0.00
# com.facebook.orca                           0.00
# com.supercell.clashofclans                  0.00
# com.cleanmaster.mguard                      0.00
# com.google.android.youtube                  0.00
# com.kiloo.subwaysurf                        0.00
# com.supercell.clashroyale                   0.00
# com.cleanmaster.security                    0.00
# com.king.candycrushsaga                     0.00
# com.dts.freefireth                          0.00
# com.UCMobile.intl                           0.00
# com.snapchat.android                        0.00
# com.qihoo.security                          0.00
# com.google.android.apps.photos              0.00
# com.miniclip.eightballpool                  0.00
# com.outfit7.mytalkingtomfree                0.00
# com.spotify.music                           0.00
# com.tencent.ig                              0.00
# com.android.chrome                          0.00
# com.twitter.android                         0.00
# com.bbm                                     0.00
# com.viber.voip                              0.00
# com.nekki.shadowfight                       0.00
# com.mobile.legends                          0.00
# com.nianticlabs.pokemongo                   0.00
# com.firsttouchgames.dls3                    0.00
# jp.naver.line.android                       0.00
# com.google.android.googlequicksearchbox     0.00
# ...                                          ...
# com.mobieslworld.kannadatoenglishspeaking   0.00
# io.influents.InfluentsPlatform.Influents    0.00
# solo.guti.new                               0.00
# com.speedymarks.android.daily               0.99
# com.gz.gzcard                               0.00
# com.gz.gzjttech.jintustar                   0.00
# solutions.bns.suigasbillcalculator          0.00
# com.baentm.dekoplay                         0.00
# com.gymfitnesscare.situpsworkout            0.00
# com.vhuntpvtltd.Jobs_and_Scholarship        0.00
# com.conjugate.theme.honor10.launcher        0.00
# com.badli.free.apps.sindhi.keyboard         0.00
# com.viastreaming.RadioGlobalPhilippines     0.00
# com.gyaansankalp                            0.00
# com.mobile.casumoo                          0.00
# com.gyana.assamesenewnewspaper              0.00
# com.gyana.hindinewnewspaper                 0.00
# com.gyana.newassamesevideos                 0.00
# io.ionic.alhuda                             0.00
# next.launcher.memscape.theme.schilds        1.49
# com.mobile.bonrix.harsrecharge              0.00
# com.viaboards.mobile.crowley                0.00
# com.mobile.app.pengg                        0.00
# next.launcher.tapanifirst.theme.snow        2.49
# com.viaberry.vconnectsv                     0.00
# com.gyanpot.LiveNewsTrend                   0.00
# com.conietech.birdlistus                    0.00
# solutions.insane.calculator                 0.00
# io.ionic.HukambossSecurityApp               0.00
# com.rayan.usacalender                       0.00
#
#                                                                   inapp_details  \
# com.whatsapp                                                               null
# com.facebook.katana                        Contains Ads·Offers in-app purchases
# com.instagram.android                                              Contains Ads
# com.facebook.orca                                       Offers in-app purchases
# com.supercell.clashofclans                              Offers in-app purchases
# com.cleanmaster.mguard                     Contains Ads·Offers in-app purchases
# com.google.android.youtube                                         Contains Ads
# com.kiloo.subwaysurf                       Contains Ads·Offers in-app purchases
# com.supercell.clashroyale                               Offers in-app purchases
# com.cleanmaster.security                   Contains Ads·Offers in-app purchases
# com.king.candycrushsaga                                 Offers in-app purchases
# com.dts.freefireth                                      Offers in-app purchases
# com.UCMobile.intl                                                  Contains Ads
# com.snapchat.android                                               Contains Ads
# com.qihoo.security                         Contains Ads·Offers in-app purchases
# com.google.android.apps.photos                                             null
# com.miniclip.eightballpool                 Contains Ads·Offers in-app purchases
# com.outfit7.mytalkingtomfree               Contains Ads·Offers in-app purchases
# com.spotify.music                                                  Contains Ads
# com.tencent.ig                                          Offers in-app purchases
# com.android.chrome                                                         null
# com.twitter.android                                                Contains Ads
# com.bbm                                    Contains Ads·Offers in-app purchases
# com.viber.voip                             Contains Ads·Offers in-app purchases
# com.nekki.shadowfight                      Contains Ads·Offers in-app purchases
# com.mobile.legends                         Contains Ads·Offers in-app purchases
# com.nianticlabs.pokemongo                               Offers in-app purchases
# com.firsttouchgames.dls3                   Contains Ads·Offers in-app purchases
# jp.naver.line.android                      Contains Ads·Offers in-app purchases
# com.google.android.googlequicksearchbox                            Contains Ads
# ...                                                                         ...
# com.mobieslworld.kannadatoenglishspeaking                          Contains Ads
# io.influents.InfluentsPlatform.Influents                                   null
# solo.guti.new                                                      Contains Ads
# com.speedymarks.android.daily                                              null
# com.gz.gzcard                                                              null
# com.gz.gzjttech.jintustar                                                  null
# solutions.bns.suigasbillcalculator                                 Contains Ads
# com.baentm.dekoplay                                                Contains Ads
# com.gymfitnesscare.situpsworkout                                   Contains Ads
# com.vhuntpvtltd.Jobs_and_Scholarship                               Contains Ads
# com.conjugate.theme.honor10.launcher                               Contains Ads
# com.badli.free.apps.sindhi.keyboard                                Contains Ads
# com.viastreaming.RadioGlobalPhilippines                                    null
# com.gyaansankalp                                                           null
# com.mobile.casumoo                                                         null
# com.gyana.assamesenewnewspaper                                     Contains Ads
# com.gyana.hindinewnewspaper                                        Contains Ads
# com.gyana.newassamesevideos                                        Contains Ads
# io.ionic.alhuda                                                            null
# next.launcher.memscape.theme.schilds                                       null
# com.mobile.bonrix.harsrecharge                                             null
# com.viaboards.mobile.crowley                                               null
# com.mobile.app.pengg                                               Contains Ads
# next.launcher.tapanifirst.theme.snow                                       null
# com.viaberry.vconnectsv                                                    null
# com.gyanpot.LiveNewsTrend                                          Contains Ads
# com.conietech.birdlistus                                                   null
# solutions.insane.calculator                                                null
# io.ionic.HukambossSecurityApp                                              null
# com.rayan.usacalender                                              Contains Ads
#
#                                            has_video  num_screenshot  ...  \
# com.whatsapp                                   False               6  ...
# com.facebook.katana                            False               5  ...
# com.instagram.android                          False               5  ...
# com.facebook.orca                              False               8  ...
# com.supercell.clashofclans                      True              21  ...
# com.cleanmaster.mguard                          True               6  ...
# com.google.android.youtube                     False               5  ...
# com.kiloo.subwaysurf                            True              25  ...
# com.supercell.clashroyale                       True              19  ...
# com.cleanmaster.security                       False               7  ...
# com.king.candycrushsaga                         True              19  ...
# com.dts.freefireth                              True              19  ...
# com.UCMobile.intl                               True               9  ...
# com.snapchat.android                           False               4  ...
# com.qihoo.security                              True               9  ...
# com.google.android.apps.photos                 False              18  ...
# com.miniclip.eightballpool                      True              13  ...
# com.outfit7.mytalkingtomfree                   False              18  ...
# com.spotify.music                              False              14  ...
# com.tencent.ig                                  True              19  ...
# com.android.chrome                             False              18  ...
# com.twitter.android                             True              11  ...
# com.bbm                                        False              13  ...
# com.viber.voip                                 False               7  ...
# com.nekki.shadowfight                           True              25  ...
# com.mobile.legends                              True              16  ...
# com.nianticlabs.pokemongo                      False              14  ...
# com.firsttouchgames.dls3                        True              16  ...
# jp.naver.line.android                          False               8  ...
# com.google.android.googlequicksearchbox        False              26  ...
# ...                                              ...             ...  ...
# com.mobieslworld.kannadatoenglishspeaking      False               4  ...
# io.influents.InfluentsPlatform.Influents       False               4  ...
# solo.guti.new                                  False               3  ...
# com.speedymarks.android.daily                  False               4  ...
# com.gz.gzcard                                  False               2  ...
# com.gz.gzjttech.jintustar                      False               6  ...
# solutions.bns.suigasbillcalculator             False               8  ...
# com.baentm.dekoplay                            False               6  ...
# com.gymfitnesscare.situpsworkout               False               5  ...
# com.vhuntpvtltd.Jobs_and_Scholarship           False               3  ...
# com.conjugate.theme.honor10.launcher           False               5  ...
# com.badli.free.apps.sindhi.keyboard            False              14  ...
# com.viastreaming.RadioGlobalPhilippines        False               8  ...
# com.gyaansankalp                               False               3  ...
# com.mobile.casumoo                             False               3  ...
# com.gyana.assamesenewnewspaper                 False               9  ...
# com.gyana.hindinewnewspaper                    False              12  ...
# com.gyana.newassamesevideos                    False               8  ...
# io.ionic.alhuda                                False               6  ...
# next.launcher.memscape.theme.schilds           False               8  ...
# com.mobile.bonrix.harsrecharge                 False              15  ...
# com.viaboards.mobile.crowley                   False               2  ...
# com.mobile.app.pengg                           False               4  ...
# next.launcher.tapanifirst.theme.snow           False               8  ...
# com.viaberry.vconnectsv                         True               8  ...
# com.gyanpot.LiveNewsTrend                      False               5  ...
# com.conietech.birdlistus                       False               3  ...
# solutions.insane.calculator                    False               2  ...
# io.ionic.HukambossSecurityApp                  False               3  ...
# com.rayan.usacalender                          False               5  ...
#
#                                            rating_2  rating_1  rating_count  \
# com.whatsapp                                2118908   5344252      87499059
# com.facebook.katana                         3499060  10113178      86433210
# com.instagram.android                       1448081   3356089      80808062
# com.facebook.orca                           2502559   7830646      65957119
# com.supercell.clashofclans                   737549   2093231      48650861
# com.cleanmaster.mguard                       519694    975487      44229745
# com.google.android.youtube                  1092518   3363947      43487619
# com.kiloo.subwaysurf                         695792   1516050      29993489
# com.supercell.clashroyale                    331601   1490455      25698937
# com.cleanmaster.security                     296582    531227      25579290
# com.king.candycrushsaga                      549362   1130414      24819484
# com.dts.freefireth                           365781   1553339      22905393
# com.UCMobile.intl                            444540   1026548      19682373
# com.snapchat.android                         759982   2520625      19156563
# com.qihoo.security                           276235    498560      16825191
# com.google.android.apps.photos               272699    574851      16675756
# com.miniclip.eightballpool                   273458    752660      16134818
# com.outfit7.mytalkingtomfree                 405297    858775      15603686
# com.spotify.music                            238977    598006      14849702
# com.tencent.ig                               238493   1136188      14782716
# com.android.chrome                           397507    964591      13968434
# com.twitter.android                          382775    930020      13072112
# com.bbm                                      436673    716887      12969994
# com.viber.voip                               394564    790058      12784985
# com.nekki.shadowfight                        175501    490056      11943119
# com.mobile.legends                           275869   1102047      11699638
# com.nianticlabs.pokemongo                    400585   1504627      11693206
# com.firsttouchgames.dls3                     157542    456075      11607232
# jp.naver.line.android                        460862    982291      11436093
# com.google.android.googlequicksearchbox      248078    716634      11088227
# ...                                             ...       ...           ...
# com.mobieslworld.kannadatoenglishspeaking         0         0             1
# io.influents.InfluentsPlatform.Influents          0         0             1
# solo.guti.new                                     0         0             1
# com.speedymarks.android.daily                     0         1             1
# com.gz.gzcard                                     0         0             1
# com.gz.gzjttech.jintustar                         0         0             1
# solutions.bns.suigasbillcalculator                0         0             1
# com.baentm.dekoplay                               0         0             1
# com.gymfitnesscare.situpsworkout                  0         1             1
# com.vhuntpvtltd.Jobs_and_Scholarship              0         0             1
# com.conjugate.theme.honor10.launcher              0         0             1
# com.badli.free.apps.sindhi.keyboard               0         0             1
# com.viastreaming.RadioGlobalPhilippines           0         0             1
# com.gyaansankalp                                  0         0             1
# com.mobile.casumoo                                0         1             1
# com.gyana.assamesenewnewspaper                    0         0             1
# com.gyana.hindinewnewspaper                       0         0             1
# com.gyana.newassamesevideos                       0         0             1
# io.ionic.alhuda                                   0         0             1
# next.launcher.memscape.theme.schilds              0         0             1
# com.mobile.bonrix.harsrecharge                    0         0             1
# com.viaboards.mobile.crowley                      0         1             1
# com.mobile.app.pengg                              0         0             1
# next.launcher.tapanifirst.theme.snow              0         0             1
# com.viaberry.vconnectsv                           0         0             1
# com.gyanpot.LiveNewsTrend                         0         0             1
# com.conietech.birdlistus                          0         0             1
# solutions.insane.calculator                       0         0             1
# io.ionic.HukambossSecurityApp                     0         0             1
# com.rayan.usacalender                             0         0             1
#
#                                            update_time                size  \
# com.whatsapp                                2019-04-24  Varies with device
# com.facebook.katana                         2019-04-25  Varies with device
# com.instagram.android                       2019-04-23  Varies with device
# com.facebook.orca                           2019-04-23  Varies with device
# com.supercell.clashofclans                  2019-04-23                103M
# com.cleanmaster.mguard                      2019-04-22                 20M
# com.google.android.youtube                  2019-04-19  Varies with device
# com.kiloo.subwaysurf                        2019-04-25                 88M
# com.supercell.clashroyale                   2019-04-15                 87M
# com.cleanmaster.security                    2019-04-22                 22M
# com.king.candycrushsaga                     2019-04-25                 87M
# com.dts.freefireth                          2019-03-30                 64M
# com.UCMobile.intl                           2019-04-15                 45M
# com.snapchat.android                        2019-04-23                 56M
# com.qihoo.security                          2019-04-25                 25M
# com.google.android.apps.photos              2019-04-25  Varies with device
# com.miniclip.eightballpool                  2019-04-17                 56M
# com.outfit7.mytalkingtomfree                2019-04-18  Varies with device
# com.spotify.music                           2019-04-23  Varies with device
# com.tencent.ig                              2019-04-17                 42M
# com.android.chrome                          2019-04-25  Varies with device
# com.twitter.android                         2019-04-24  Varies with device
# com.bbm                                     2019-03-25                 45M
# com.viber.voip                              2019-04-21  Varies with device
# com.nekki.shadowfight                       2019-04-17                 30M
# com.mobile.legends                          2019-04-16                 96M
# com.nianticlabs.pokemongo                   2019-04-25                 96M
# com.firsttouchgames.dls3                    2019-03-14                 72M
# jp.naver.line.android                       2019-04-23                 94M
# com.google.android.googlequicksearchbox     2019-04-23  Varies with device
# ...                                                ...                 ...
# com.mobieslworld.kannadatoenglishspeaking   2019-03-23                4.0M
# io.influents.InfluentsPlatform.Influents    2017-10-23                7.7M
# solo.guti.new                               2019-03-25                8.1M
# com.speedymarks.android.daily               2012-09-12                 95k
# com.gz.gzcard                               2018-04-04                 13M
# com.gz.gzjttech.jintustar                   2019-02-15                 13M
# solutions.bns.suigasbillcalculator          2019-03-11                3.7M
# com.baentm.dekoplay                         2019-04-04                7.2M
# com.gymfitnesscare.situpsworkout            2019-01-25                 14M
# com.vhuntpvtltd.Jobs_and_Scholarship        2019-01-19                4.6M
# com.conjugate.theme.honor10.launcher        2019-04-13                 10M
# com.badli.free.apps.sindhi.keyboard         2019-02-14                7.9M
# com.viastreaming.RadioGlobalPhilippines     2017-12-11                1.2M
# ...
# com.vhuntpvtltd.Jobs_and_Scholarship                10                 1.0
# com.conjugate.theme.honor10.launcher              1000                 1.2
# com.badli.free.apps.sindhi.keyboard                 50                 1.0
# com.viastreaming.RadioGlobalPhilippines             50                 1.0
# com.gyaansankalp                                    10                   3
# com.mobile.casumoo                                  50                 1.0
# com.gyana.assamesenewnewspaper                     100               2.0.5
# com.gyana.hindinewnewspaper                         50               2.0.5
# com.gyana.newassamesevideos                        500               1.0.5
# io.ionic.alhuda                                     10               1.0.2
# next.launcher.memscape.theme.schilds                10                4.71
# com.mobile.bonrix.harsrecharge                     500                 1.4
# com.viaboards.mobile.crowley                       100               1.0.0
# com.mobile.app.pengg                                10               1.4.3
# next.launcher.tapanifirst.theme.snow               100                4.74
# com.viaberry.vconnectsv                             10              1.3.12
# com.gyanpot.LiveNewsTrend                           10                 1.0
# com.conietech.birdlistus                           100                 1.1
# solutions.insane.calculator                          1               1.0.0
# io.ionic.HukambossSecurityApp                       10               0.0.8
# com.rayan.usacalender                                1                 1.0
#
#                                               android_version  \
# com.whatsapp                               Varies with device
# com.facebook.katana                        Varies with device
# com.instagram.android                      Varies with device
# com.facebook.orca                          Varies with device
# com.supercell.clashofclans                         4.1 and up
# com.cleanmaster.mguard                     Varies with device
# com.google.android.youtube                 Varies with device
# com.kiloo.subwaysurf                               4.1 and up
# com.supercell.clashroyale                          4.1 and up
# com.cleanmaster.security                   Varies with device
# com.king.candycrushsaga                            4.1 and up
# com.dts.freefireth                               4.0.3 and up
# com.UCMobile.intl                                  4.0 and up
# com.snapchat.android                               4.4 and up
# com.qihoo.security                                 4.1 and up
# com.google.android.apps.photos             Varies with device
# com.miniclip.eightballpool                       4.0.3 and up
# com.outfit7.mytalkingtomfree                       4.1 and up
# com.spotify.music                          Varies with device
# com.tencent.ig                                     4.3 and up
# com.android.chrome                         Varies with device
# com.twitter.android                        Varies with device
# com.bbm                                            4.1 and up
# com.viber.voip                                     4.1 and up
# com.nekki.shadowfight                              4.1 and up
# com.mobile.legends                               4.0.3 and up
# com.nianticlabs.pokemongo                          4.4 and up
# com.firsttouchgames.dls3                           4.4 and up
# jp.naver.line.android                              4.4 and up
# com.google.android.googlequicksearchbox    Varies with device
# ...                                                       ...
# com.mobieslworld.kannadatoenglishspeaking          4.2 and up
# io.influents.InfluentsPlatform.Influents           4.1 and up
# solo.guti.new                                    4.0.3 and up
# com.speedymarks.android.daily                      1.1 and up
# com.gz.gzcard                                      4.1 and up
# com.gz.gzjttech.jintustar                          4.2 and up
# solutions.bns.suigasbillcalculator                 4.4 and up
# com.baentm.dekoplay                                4.1 and up
# com.gymfitnesscare.situpsworkout                   4.1 and up
# com.vhuntpvtltd.Jobs_and_Scholarship               4.4 and up
# com.conjugate.theme.honor10.launcher               4.1 and up
# com.badli.free.apps.sindhi.keyboard              4.0.3 and up
# com.viastreaming.RadioGlobalPhilippines            2.2 and up
# com.gyaansankalp                                   5.0 and up
# com.mobile.casumoo                                 4.0 and up
# com.gyana.assamesenewnewspaper                   4.0.3 and up
# com.gyana.hindinewnewspaper                      4.0.3 and up
# com.gyana.newassamesevideos                        4.1 and up
# io.ionic.alhuda                                    4.4 and up
# next.launcher.memscape.theme.schilds               1.6 and up
# com.mobile.bonrix.harsrecharge                     4.1 and up
# com.viaboards.mobile.crowley                       4.4 and up
# com.mobile.app.pengg                               4.2 and up
# next.launcher.tapanifirst.theme.snow               1.6 and up
# com.viaberry.vconnectsv                           4.4W and up
# com.gyanpot.LiveNewsTrend                        4.0.3 and up
# com.conietech.birdlistus                           4.4 and up
# solutions.insane.calculator                        4.4 and up
# io.ionic.HukambossSecurityApp                      4.1 and up
# com.rayan.usacalender                              4.4 and up
#
#                                                                         interactive_elements  \
# com.whatsapp                                               Users Interact, Digital Purchases
# com.facebook.katana                        Users Interact, Shares Info, Shares Location, ...
# com.instagram.android                           Users Interact, Shares Info, Shares Location
# com.facebook.orca                          Users Interact, Shares Location, Digital Purch...
# com.supercell.clashofclans                                 Users Interact, Digital Purchases
# com.cleanmaster.mguard                                                                   NaN
# com.google.android.youtube                                 Users Interact, Digital Purchases
# com.kiloo.subwaysurf                                                       Digital Purchases
# com.supercell.clashroyale                                  Users Interact, Digital Purchases
# com.cleanmaster.security                                                   Digital Purchases
# com.king.candycrushsaga                       Users Interact, Shares Info, Digital Purchases
# com.dts.freefireth                                         Users Interact, In-Game Purchases
# com.UCMobile.intl                                                      Unrestricted Internet
# com.snapchat.android                          Users Interact, Shares Info, Digital Purchases
# com.qihoo.security                                                                       NaN
# com.google.android.apps.photos                                                           NaN
# com.miniclip.eightballpool                                                 Digital Purchases
# com.outfit7.mytalkingtomfree                               Users Interact, Digital Purchases
# com.spotify.music                                                Users Interact, Shares Info
# com.tencent.ig                                             Users Interact, Digital Purchases
# com.android.chrome                                                     Unrestricted Internet
# com.twitter.android                                          Users Interact, Shares Location
# com.bbm                                                    Users Interact, Digital Purchases
# com.viber.voip                             Users Interact, Shares Info, Shares Location, ...
# com.nekki.shadowfight                                      Users Interact, Digital Purchases
# com.mobile.legends                                         Users Interact, Digital Purchases
# com.nianticlabs.pokemongo                  Users Interact, Shares Info, Shares Location, ...
# com.firsttouchgames.dls3                                                   Digital Purchases
# jp.naver.line.android                      Users Interact, Shares Location, Digital Purch...
# com.google.android.googlequicksearchbox                                Unrestricted Internet
# ...                                                                                      ...
# com.mobieslworld.kannadatoenglishspeaking                                                NaN
# io.influents.InfluentsPlatform.Influents                                                 NaN
# solo.guti.new                                                                            NaN
# com.speedymarks.android.daily                                                            NaN
# com.gz.gzcard                                                                            NaN
# com.gz.gzjttech.jintustar                                                                NaN
# solutions.bns.suigasbillcalculator                                                       NaN
# com.baentm.dekoplay                                                                      NaN
# com.gymfitnesscare.situpsworkout                                                         NaN
# com.vhuntpvtltd.Jobs_and_Scholarship                                                     NaN
# com.conjugate.theme.honor10.launcher                                                     NaN
# com.badli.free.apps.sindhi.keyboard                                                      NaN
# com.viastreaming.RadioGlobalPhilippines                                                  NaN
# com.gyaansankalp                                                                         NaN
# com.mobile.casumoo                                                                       NaN
# com.gyana.assamesenewnewspaper                                                           NaN
# com.gyana.hindinewnewspaper                                                              NaN
# com.gyana.newassamesevideos                                                              NaN
# io.ionic.alhuda                                                                          NaN
# next.launcher.memscape.theme.schilds                                                     NaN
# com.mobile.bonrix.harsrecharge                                                           NaN
# com.viaboards.mobile.crowley                                 Users Interact, Shares Location
# com.mobile.app.pengg                                         Users Interact, Shares Location
# next.launcher.tapanifirst.theme.snow                                                     NaN
# com.viaberry.vconnectsv                                                                  NaN
# com.gyanpot.LiveNewsTrend                                                                NaN
# com.conietech.birdlistus                                                                 NaN
# solutions.insane.calculator                                                              NaN
# io.ionic.HukambossSecurityApp                                          Unrestricted Internet
# com.rayan.usacalender                                                                    NaN
#
#                                                     in_app_products
# com.whatsapp                                                    NaN
# com.facebook.katana                        $0.99 - $399.99 per item
# com.instagram.android                                           NaN
# com.facebook.orca                          $0.99 - $399.99 per item
# com.supercell.clashofclans                 $0.99 - $100.00 per item
# com.cleanmaster.mguard                      $2.99 - $10.68 per item
# com.google.android.youtube                                      NaN
# com.kiloo.subwaysurf                        $0.99 - $99.99 per item
# com.supercell.clashroyale                   $0.99 - $99.99 per item
# com.cleanmaster.security                    $0.99 - $35.99 per item
# com.king.candycrushsaga                    $0.99 - $149.99 per item
# com.dts.freefireth                         $0.99 - $109.99 per item
# com.UCMobile.intl                                               NaN
# com.snapchat.android                                            NaN
# com.qihoo.security                          $0.99 - $62.16 per item
# com.google.android.apps.photos                                  NaN
# com.miniclip.eightballpool                  $0.99 - $99.99 per item
# com.outfit7.mytalkingtomfree                $0.99 - $99.99 per item
# com.spotify.music                                               NaN
# com.tencent.ig                             $0.99 - $199.99 per item
# com.android.chrome                                              NaN
# com.twitter.android                                             NaN
# com.bbm                                      $0.99 - $1.99 per item
# com.viber.voip                              $0.99 - $49.99 per item
# com.nekki.shadowfight                       $0.99 - $49.99 per item
# com.mobile.legends                          $0.99 - $99.99 per item
# com.nianticlabs.pokemongo                   $0.99 - $99.99 per item
# com.firsttouchgames.dls3                    $0.99 - $59.99 per item
# jp.naver.line.android                      $0.99 - $139.99 per item
# com.google.android.googlequicksearchbox                         NaN
# ...                                                             ...
# com.mobieslworld.kannadatoenglishspeaking                       NaN
# io.influents.InfluentsPlatform.Influents                        NaN
# solo.guti.new                                                   NaN
# com.speedymarks.android.daily                                   NaN
# com.gz.gzcard                                                   NaN
# com.gz.gzjttech.jintustar                                       NaN
# solutions.bns.suigasbillcalculator                              NaN
# com.baentm.dekoplay                                             NaN
# com.gymfitnesscare.situpsworkout                                NaN
# com.vhuntpvtltd.Jobs_and_Scholarship                            NaN
# com.conjugate.theme.honor10.launcher                            NaN
# com.badli.free.apps.sindhi.keyboard                             NaN
# com.viastreaming.RadioGlobalPhilippines                         NaN
# com.gyaansankalp                                                NaN
# com.mobile.casumoo                                              NaN
# com.gyana.assamesenewnewspaper                                  NaN
# com.gyana.hindinewnewspaper                                     NaN
# com.gyana.newassamesevideos                                     NaN
# io.ionic.alhuda                                                 NaN
# next.launcher.memscape.theme.schilds                            NaN
# com.mobile.bonrix.harsrecharge                                  NaN
# com.viaboards.mobile.crowley                                    NaN
# com.mobile.app.pengg                                            NaN
# next.launcher.tapanifirst.theme.snow                            NaN
# com.viaberry.vconnectsv                                         NaN
# com.gyanpot.LiveNewsTrend                                       NaN
# com.conietech.birdlistus                                        NaN
# solutions.insane.calculator                                     NaN
# io.ionic.HukambossSecurityApp                                   NaN
# com.rayan.usacalender                                           NaN
#
# [642744 rows x 24 columns]

# %%
df_sorted.to_csv('data_essential.csv', index=False)
